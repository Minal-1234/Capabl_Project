# %% [markdown]
# # Major Project 2: Data Analysis And Visualization - IPL

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('IPL Ball-by-Ball 2008-2020.csv')

# %%
df
# Out:
#              id  inning  over  ball      batsman  non_striker  \
# 0        335982       1     6     5   RT Ponting  BB McCullum
# 1        335982       1     6     6  BB McCullum   RT Ponting
# 2        335982       1     7     1  BB McCullum   RT Ponting
# 3        335982       1     7     2  BB McCullum   RT Ponting
# 4        335982       1     7     3   RT Ponting  BB McCullum
# ...         ...     ...   ...   ...          ...          ...
# 193463  1237181       1    12     5      RR Pant      SS Iyer
# 193464  1237181       1    12     6      RR Pant      SS Iyer
# 193465  1237181       1    13     1      RR Pant      SS Iyer
# 193466  1237181       1    13     2      RR Pant      SS Iyer
# 193467  1237181       1    13     3      SS Iyer      RR Pant
#
#                  bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 0             AA Noffke             1           0           1             0
# 1             AA Noffke             1           0           1             0
# 2                Z Khan             0           0           0             0
# 3                Z Khan             1           0           1             0
# 4                Z Khan             1           0           1             0
# ...                 ...           ...         ...         ...           ...
# 193463  NM Coulter-Nile             0           0           0             0
# 193464  NM Coulter-Nile             1           0           1             0
# 193465        KH Pandya             0           1           1             0
# 193466        KH Pandya             1           0           1             0
# 193467        KH Pandya             1           0           1             0
#
#         is_wicket dismissal_kind player_dismissed fielder extras_type  \
# 0               0            NaN              NaN     NaN         NaN
# 1               0            NaN              NaN     NaN         NaN
# 2               0            NaN              NaN     NaN         NaN
# 3               0            NaN              NaN     NaN         NaN
# 4               0            NaN              NaN     NaN         NaN
# ...           ...            ...              ...     ...         ...
# 193463          0            NaN              NaN     NaN         NaN
# 193464          0            NaN              NaN     NaN         NaN
# 193465          0            NaN              NaN     NaN       wides
# 193466          0            NaN              NaN     NaN         NaN
# 193467          0            NaN              NaN     NaN         NaN
#
#                  batting_team                 bowling_team
# 0       Kolkata Knight Riders  Royal Challengers Bangalore
# 1       Kolkata Knight Riders  Royal Challengers Bangalore
# 2       Kolkata Knight Riders  Royal Challengers Bangalore
# 3       Kolkata Knight Riders  Royal Challengers Bangalore
# 4       Kolkata Knight Riders  Royal Challengers Bangalore
# ...                       ...                          ...
# 193463         Delhi Capitals               Mumbai Indians
# 193464         Delhi Capitals               Mumbai Indians
# 193465         Delhi Capitals               Mumbai Indians
# 193466         Delhi Capitals               Mumbai Indians
# 193467         Delhi Capitals               Mumbai Indians
#
# [193468 rows x 18 columns]

# %%
df1 = pd.read_csv('IPL Matches 2008-2020.csv')

# %%
df1
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# 4                                  Eden Gardens              0
# ..                                          ...            ...
# 811         Dubai International Cricket Stadium              0
# 812         Dubai International Cricket Stadium              0
# 813                        Sheikh Zayed Stadium              0
# 814                        Sheikh Zayed Stadium              0
# 815         Dubai International Cricket Stadium              0
#
#                            team1                        team2  \
# 0    Royal Challengers Bangalore        Kolkata Knight Riders
# 1                Kings XI Punjab          Chennai Super Kings
# 2               Delhi Daredevils             Rajasthan Royals
# 3                 Mumbai Indians  Royal Challengers Bangalore
# 4          Kolkata Knight Riders              Deccan Chargers
# ..                           ...                          ...
# 811  Royal Challengers Bangalore               Mumbai Indians
# 812               Mumbai Indians               Delhi Capitals
# 813  Royal Challengers Bangalore          Sunrisers Hyderabad
# 814               Delhi Capitals          Sunrisers Hyderabad
# 815               Delhi Capitals               Mumbai Indians
#
#                      toss_winner toss_decision                       winner  \
# 0    Royal Challengers Bangalore         field        Kolkata Knight Riders
# 1            Chennai Super Kings           bat          Chennai Super Kings
# 2               Rajasthan Royals           bat             Delhi Daredevils
# 3                 Mumbai Indians           bat  Royal Challengers Bangalore
# 4                Deccan Chargers           bat        Kolkata Knight Riders
# ..                           ...           ...                          ...
# 811               Mumbai Indians         field  Royal Challengers Bangalore
# 812               Delhi Capitals         field               Mumbai Indians
# 813          Sunrisers Hyderabad         field          Sunrisers Hyderabad
# 814               Delhi Capitals           bat               Delhi Capitals
# 815               Delhi Capitals           bat               Mumbai Indians
#
#       result  result_margin eliminator method      umpire1         umpire2
# 0       runs          140.0          N    NaN    Asad Rauf     RE Koertzen
# 1       runs           33.0          N    NaN    MR Benson      SL Shastri
# 2    wickets            9.0          N    NaN    Aleem Dar  GA Pratapkumar
# 3    wickets            5.0          N    NaN     SJ Davis       DJ Harper
# 4    wickets            5.0          N    NaN    BF Bowden     K Hariharan
# ..       ...            ...        ...    ...          ...             ...
# 811      tie            NaN          Y    NaN  Nitin Menon      PR Reiffel
# 812     runs           57.0          N    NaN  CB Gaffaney     Nitin Menon
# 813  wickets            6.0          N    NaN   PR Reiffel          S Ravi
# 814     runs           17.0          N    NaN   PR Reiffel          S Ravi
# 815  wickets            5.0          N    NaN  CB Gaffaney     Nitin Menon
#
# [816 rows x 17 columns]

# %% [markdown]
# #### Studing df

# %%
df
# Out:
#              id  inning  over  ball      batsman  non_striker  \
# 0        335982       1     6     5   RT Ponting  BB McCullum
# 1        335982       1     6     6  BB McCullum   RT Ponting
# 2        335982       1     7     1  BB McCullum   RT Ponting
# 3        335982       1     7     2  BB McCullum   RT Ponting
# 4        335982       1     7     3   RT Ponting  BB McCullum
# ...         ...     ...   ...   ...          ...          ...
# 193463  1237181       1    12     5      RR Pant      SS Iyer
# 193464  1237181       1    12     6      RR Pant      SS Iyer
# 193465  1237181       1    13     1      RR Pant      SS Iyer
# 193466  1237181       1    13     2      RR Pant      SS Iyer
# 193467  1237181       1    13     3      SS Iyer      RR Pant
#
#                  bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 0             AA Noffke             1           0           1             0
# 1             AA Noffke             1           0           1             0
# 2                Z Khan             0           0           0             0
# 3                Z Khan             1           0           1             0
# 4                Z Khan             1           0           1             0
# ...                 ...           ...         ...         ...           ...
# 193463  NM Coulter-Nile             0           0           0             0
# 193464  NM Coulter-Nile             1           0           1             0
# 193465        KH Pandya             0           1           1             0
# 193466        KH Pandya             1           0           1             0
# 193467        KH Pandya             1           0           1             0
#
#         is_wicket dismissal_kind player_dismissed fielder extras_type  \
# 0               0            NaN              NaN     NaN         NaN
# 1               0            NaN              NaN     NaN         NaN
# 2               0            NaN              NaN     NaN         NaN
# 3               0            NaN              NaN     NaN         NaN
# 4               0            NaN              NaN     NaN         NaN
# ...           ...            ...              ...     ...         ...
# 193463          0            NaN              NaN     NaN         NaN
# 193464          0            NaN              NaN     NaN         NaN
# 193465          0            NaN              NaN     NaN       wides
# 193466          0            NaN              NaN     NaN         NaN
# 193467          0            NaN              NaN     NaN         NaN
#
#                  batting_team                 bowling_team
# 0       Kolkata Knight Riders  Royal Challengers Bangalore
# 1       Kolkata Knight Riders  Royal Challengers Bangalore
# 2       Kolkata Knight Riders  Royal Challengers Bangalore
# 3       Kolkata Knight Riders  Royal Challengers Bangalore
# 4       Kolkata Knight Riders  Royal Challengers Bangalore
# ...                       ...                          ...
# 193463         Delhi Capitals               Mumbai Indians
# 193464         Delhi Capitals               Mumbai Indians
# 193465         Delhi Capitals               Mumbai Indians
# 193466         Delhi Capitals               Mumbai Indians
# 193467         Delhi Capitals               Mumbai Indians
#
# [193468 rows x 18 columns]

# %%
df['id'].isnull().sum()
# Out:
# 0

# %%
df['inning'].isnull().sum()
# Out:
# 0

# %%
df['over'].isnull().sum()
# Out:
# 0

# %%
df['ball'].isnull().sum()
# Out:
# 0

# %%
df['batsman'].isnull().sum()
# Out:
# 0

# %%
df['non_striker'].isnull().sum()
# Out:
# 0

# %%
df['bowler'].isnull().sum()
# Out:
# 0

# %%
df['batsman_runs'].isnull().sum()
# Out:
# 0

# %%
df['extra_runs'].isnull().sum()
# Out:
# 0

# %%
df['total_runs'].isnull().sum()
# Out:
# 0

# %%
df['non_boundary'].isnull().sum()
# Out:
# 0

# %%
df['is_wicket'].isnull().sum()
# Out:
# 0

# %%
df['dismissal_kind'].isnull().sum()  #deleted
# Out:
# 183973

# %%
df['player_dismissed'].isnull().sum()  #deleted
# Out:
# 183973

# %%
df['fielder'].isnull().sum()
# Out:
# 186684

# %%
df['extras_type'].isnull().sum()  #deleted
# Out:
# 183235

# %%
df['batting_team'].isnull().sum()
# Out:
# 0

# %%
df['bowling_team'].isnull().sum()
# Out:
# 191

# %%
del df['fielder']

# %%
del df['dismissal_kind']

# %%
del df['player_dismissed']

# %%
del df['extras_type']

# %%
df
# Out:
#              id  inning  over  ball      batsman  non_striker  \
# 0        335982       1     6     5   RT Ponting  BB McCullum
# 1        335982       1     6     6  BB McCullum   RT Ponting
# 2        335982       1     7     1  BB McCullum   RT Ponting
# 3        335982       1     7     2  BB McCullum   RT Ponting
# 4        335982       1     7     3   RT Ponting  BB McCullum
# ...         ...     ...   ...   ...          ...          ...
# 193463  1237181       1    12     5      RR Pant      SS Iyer
# 193464  1237181       1    12     6      RR Pant      SS Iyer
# 193465  1237181       1    13     1      RR Pant      SS Iyer
# 193466  1237181       1    13     2      RR Pant      SS Iyer
# 193467  1237181       1    13     3      SS Iyer      RR Pant
#
#                  bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 0             AA Noffke             1           0           1             0
# 1             AA Noffke             1           0           1             0
# 2                Z Khan             0           0           0             0
# 3                Z Khan             1           0           1             0
# 4                Z Khan             1           0           1             0
# ...                 ...           ...         ...         ...           ...
# 193463  NM Coulter-Nile             0           0           0             0
# 193464  NM Coulter-Nile             1           0           1             0
# 193465        KH Pandya             0           1           1             0
# 193466        KH Pandya             1           0           1             0
# 193467        KH Pandya             1           0           1             0
#
#         is_wicket           batting_team                 bowling_team
# 0               0  Kolkata Knight Riders  Royal Challengers Bangalore
# 1               0  Kolkata Knight Riders  Royal Challengers Bangalore
# 2               0  Kolkata Knight Riders  Royal Challengers Bangalore
# 3               0  Kolkata Knight Riders  Royal Challengers Bangalore
# 4               0  Kolkata Knight Riders  Royal Challengers Bangalore
# ...           ...                    ...                          ...
# 193463          0         Delhi Capitals               Mumbai Indians
# 193464          0         Delhi Capitals               Mumbai Indians
# 193465          0         Delhi Capitals               Mumbai Indians
# 193466          0         Delhi Capitals               Mumbai Indians
# 193467          0         Delhi Capitals               Mumbai Indians
#
# [193468 rows x 14 columns]

# %%
#Filling NULL values in the bowling_team column
df['bowling_team'] = df['bowling_team'].fillna('Anonymous')

# %%
df
# Out:
#              id  inning  over  ball      batsman  non_striker  \
# 0        335982       1     6     5   RT Ponting  BB McCullum
# 1        335982       1     6     6  BB McCullum   RT Ponting
# 2        335982       1     7     1  BB McCullum   RT Ponting
# 3        335982       1     7     2  BB McCullum   RT Ponting
# 4        335982       1     7     3   RT Ponting  BB McCullum
# ...         ...     ...   ...   ...          ...          ...
# 193463  1237181       1    12     5      RR Pant      SS Iyer
# 193464  1237181       1    12     6      RR Pant      SS Iyer
# 193465  1237181       1    13     1      RR Pant      SS Iyer
# 193466  1237181       1    13     2      RR Pant      SS Iyer
# 193467  1237181       1    13     3      SS Iyer      RR Pant
#
#                  bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 0             AA Noffke             1           0           1             0
# 1             AA Noffke             1           0           1             0
# 2                Z Khan             0           0           0             0
# 3                Z Khan             1           0           1             0
# 4                Z Khan             1           0           1             0
# ...                 ...           ...         ...         ...           ...
# 193463  NM Coulter-Nile             0           0           0             0
# 193464  NM Coulter-Nile             1           0           1             0
# 193465        KH Pandya             0           1           1             0
# 193466        KH Pandya             1           0           1             0
# 193467        KH Pandya             1           0           1             0
#
#         is_wicket           batting_team                 bowling_team
# 0               0  Kolkata Knight Riders  Royal Challengers Bangalore
# 1               0  Kolkata Knight Riders  Royal Challengers Bangalore
# 2               0  Kolkata Knight Riders  Royal Challengers Bangalore
# 3               0  Kolkata Knight Riders  Royal Challengers Bangalore
# 4               0  Kolkata Knight Riders  Royal Challengers Bangalore
# ...           ...                    ...                          ...
# 193463          0         Delhi Capitals               Mumbai Indians
# 193464          0         Delhi Capitals               Mumbai Indians
# 193465          0         Delhi Capitals               Mumbai Indians
# 193466          0         Delhi Capitals               Mumbai Indians
# 193467          0         Delhi Capitals               Mumbai Indians
#
# [193468 rows x 14 columns]

# %% [markdown]
# ### Studing df1

# %%
df1
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# 4                                  Eden Gardens              0
# ..                                          ...            ...
# 811         Dubai International Cricket Stadium              0
# 812         Dubai International Cricket Stadium              0
# 813                        Sheikh Zayed Stadium              0
# 814                        Sheikh Zayed Stadium              0
# 815         Dubai International Cricket Stadium              0
#
#                            team1                        team2  \
# 0    Royal Challengers Bangalore        Kolkata Knight Riders
# 1                Kings XI Punjab          Chennai Super Kings
# 2               Delhi Daredevils             Rajasthan Royals
# 3                 Mumbai Indians  Royal Challengers Bangalore
# 4          Kolkata Knight Riders              Deccan Chargers
# ..                           ...                          ...
# 811  Royal Challengers Bangalore               Mumbai Indians
# 812               Mumbai Indians               Delhi Capitals
# 813  Royal Challengers Bangalore          Sunrisers Hyderabad
# 814               Delhi Capitals          Sunrisers Hyderabad
# 815               Delhi Capitals               Mumbai Indians
#
#                      toss_winner toss_decision                       winner  \
# 0    Royal Challengers Bangalore         field        Kolkata Knight Riders
# 1            Chennai Super Kings           bat          Chennai Super Kings
# 2               Rajasthan Royals           bat             Delhi Daredevils
# 3                 Mumbai Indians           bat  Royal Challengers Bangalore
# 4                Deccan Chargers           bat        Kolkata Knight Riders
# ..                           ...           ...                          ...
# 811               Mumbai Indians         field  Royal Challengers Bangalore
# 812               Delhi Capitals         field               Mumbai Indians
# 813          Sunrisers Hyderabad         field          Sunrisers Hyderabad
# 814               Delhi Capitals           bat               Delhi Capitals
# 815               Delhi Capitals           bat               Mumbai Indians
#
#       result  result_margin eliminator method      umpire1         umpire2
# 0       runs          140.0          N    NaN    Asad Rauf     RE Koertzen
# 1       runs           33.0          N    NaN    MR Benson      SL Shastri
# 2    wickets            9.0          N    NaN    Aleem Dar  GA Pratapkumar
# 3    wickets            5.0          N    NaN     SJ Davis       DJ Harper
# 4    wickets            5.0          N    NaN    BF Bowden     K Hariharan
# ..       ...            ...        ...    ...          ...             ...
# 811      tie            NaN          Y    NaN  Nitin Menon      PR Reiffel
# 812     runs           57.0          N    NaN  CB Gaffaney     Nitin Menon
# 813  wickets            6.0          N    NaN   PR Reiffel          S Ravi
# 814     runs           17.0          N    NaN   PR Reiffel          S Ravi
# 815  wickets            5.0          N    NaN  CB Gaffaney     Nitin Menon
#
# [816 rows x 17 columns]

# %%
df1['id'].isnull().sum()
# Out:
# 0

# %%
b= df1[df1['player_of_match'].isnull()].index.tolist()

# %%
b
# Out:
# [241, 486, 511, 744]

# %%
c=df1[df1['result'].isnull()].index.tolist()

# %%
c
# Out:
# [241, 486, 511, 744]

# %%
df1=df1.drop(241)

# %%
df1
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# 4                                  Eden Gardens              0
# ..                                          ...            ...
# 811         Dubai International Cricket Stadium              0
# 812         Dubai International Cricket Stadium              0
# 813                        Sheikh Zayed Stadium              0
# 814                        Sheikh Zayed Stadium              0
# 815         Dubai International Cricket Stadium              0
#
#                            team1                        team2  \
# 0    Royal Challengers Bangalore        Kolkata Knight Riders
# 1                Kings XI Punjab          Chennai Super Kings
# 2               Delhi Daredevils             Rajasthan Royals
# 3                 Mumbai Indians  Royal Challengers Bangalore
# 4          Kolkata Knight Riders              Deccan Chargers
# ..                           ...                          ...
# 811  Royal Challengers Bangalore               Mumbai Indians
# 812               Mumbai Indians               Delhi Capitals
# 813  Royal Challengers Bangalore          Sunrisers Hyderabad
# 814               Delhi Capitals          Sunrisers Hyderabad
# 815               Delhi Capitals               Mumbai Indians
#
#                      toss_winner toss_decision                       winner  \
# 0    Royal Challengers Bangalore         field        Kolkata Knight Riders
# 1            Chennai Super Kings           bat          Chennai Super Kings
# 2               Rajasthan Royals           bat             Delhi Daredevils
# 3                 Mumbai Indians           bat  Royal Challengers Bangalore
# 4                Deccan Chargers           bat        Kolkata Knight Riders
# ..                           ...           ...                          ...
# 811               Mumbai Indians         field  Royal Challengers Bangalore
# 812               Delhi Capitals         field               Mumbai Indians
# 813          Sunrisers Hyderabad         field          Sunrisers Hyderabad
# 814               Delhi Capitals           bat               Delhi Capitals
# 815               Delhi Capitals           bat               Mumbai Indians
#
#       result  result_margin eliminator method      umpire1         umpire2
# 0       runs          140.0          N    NaN    Asad Rauf     RE Koertzen
# 1       runs           33.0          N    NaN    MR Benson      SL Shastri
# 2    wickets            9.0          N    NaN    Aleem Dar  GA Pratapkumar
# 3    wickets            5.0          N    NaN     SJ Davis       DJ Harper
# 4    wickets            5.0          N    NaN    BF Bowden     K Hariharan
# ..       ...            ...        ...    ...          ...             ...
# 811      tie            NaN          Y    NaN  Nitin Menon      PR Reiffel
# 812     runs           57.0          N    NaN  CB Gaffaney     Nitin Menon
# 813  wickets            6.0          N    NaN   PR Reiffel          S Ravi
# 814     runs           17.0          N    NaN   PR Reiffel          S Ravi
# 815  wickets            5.0          N    NaN  CB Gaffaney     Nitin Menon
#
# [815 rows x 17 columns]

# %%
df1['city'].isnull().sum()
# Out:
# 13

# %%
df1['date'].isnull().sum()
# Out:
# 0

# %%
df1['player_of_match'].isnull().sum()
# Out:
# 3

# %%
df1['venue'].isnull().sum()
# Out:
# 0

# %%
df1['neutral_venue'].isnull().sum()  #deleted
# Out:
# 0

# %%
df1['team1'].isnull().sum()
# Out:
# 0

# %%
df1['team2'].isnull().sum()
# Out:
# 0

# %%
df1['toss_winner'].isnull().sum()
# Out:
# 0

# %%
df1['toss_decision'].isnull().sum()
# Out:
# 0

# %%
df1['winner'].isnull().sum()
# Out:
# 3

# %%
df1['result'].isnull().sum()
# Out:
# 3

# %%
df1['result_margin'].isnull().sum()   #deleted
# Out:
# 16

# %%
df1['eliminator'].isnull().sum()   #deleted
# Out:
# 3

# %%
df1['method'].isnull().sum()   #deleted
# Out:
# 796

# %%
df1['umpire1'].isnull().sum()
# Out:
# 0

# %%
df1['umpire2'].isnull().sum()
# Out:
# 0

# %%
del df1['method']

# %%
del df1['eliminator']

# %%
del df1['neutral_venue']

# %%
del df1['result_margin']

# %%
#Filling NULL values in the winner column
df1['winner'].fillna('Anonymous')
# Out:
# 0            Kolkata Knight Riders
# 1              Chennai Super Kings
# 2                 Delhi Daredevils
# 3      Royal Challengers Bangalore
# 4            Kolkata Knight Riders
#                   ...
# 811    Royal Challengers Bangalore
# 812                 Mumbai Indians
# 813            Sunrisers Hyderabad
# 814                 Delhi Capitals
# 815                 Mumbai Indians
# Name: winner, Length: 815, dtype: object

# %%
df1['player_of_match']=df1['player_of_match'].fillna('Anonymous')

# %%
#Filling NULL values in the city column
df1['city'].fillna('Anonymous')
# Out:
# 0       Bangalore
# 1      Chandigarh
# 2           Delhi
# 3          Mumbai
# 4         Kolkata
#           ...
# 811         Dubai
# 812         Dubai
# 813     Abu Dhabi
# 814     Abu Dhabi
# 815         Dubai
# Name: city, Length: 815, dtype: object

# %%
#Filling NULL values in the result column
df1['result'].fillna('Not Known')
# Out:
# 0         runs
# 1         runs
# 2      wickets
# 3      wickets
# 4      wickets
#         ...
# 811        tie
# 812       runs
# 813    wickets
# 814       runs
# 815    wickets
# Name: result, Length: 815, dtype: object

# %%
df.isnull().sum()
# Out:
# id              0
# inning          0
# over            0
# ball            0
# batsman         0
# non_striker     0
# bowler          0
# batsman_runs    0
# extra_runs      0
# total_runs      0
# non_boundary    0
# is_wicket       0
# batting_team    0
# bowling_team    0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# id                  0
# city               13
# date                0
# player_of_match     0
# venue               0
# team1               0
# team2               0
# toss_winner         0
# toss_decision       0
# winner              3
# result              3
# umpire1             0
# umpire2             0
# dtype: int64

# %% [markdown]
# ## 1) What was the count of matches played in each season?

# %%
df.to_csv('ipl_1.csv')
df1.to_csv('ipl_2.csv')

# %%
#Adding year column to the data frame
#step 1 - converting the str date column into int and separating year and inserting them into a list.
year = []
for i in df1['date']:
    year.append(int(i[:-6]))
print(year)
# Out:
# [2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2008, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2009, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2010, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2011, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2012, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2016, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 2018, 201 ...

# %%
# step 2 - Adding year column to the data frame
df1.loc[:, "Year"] = year

# %%
df1
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue                        team1  \
# 0                         M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1    Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                              Feroz Shah Kotla             Delhi Daredevils
# 3                              Wankhede Stadium               Mumbai Indians
# 4                                  Eden Gardens        Kolkata Knight Riders
# ..                                          ...                          ...
# 811         Dubai International Cricket Stadium  Royal Challengers Bangalore
# 812         Dubai International Cricket Stadium               Mumbai Indians
# 813                        Sheikh Zayed Stadium  Royal Challengers Bangalore
# 814                        Sheikh Zayed Stadium               Delhi Capitals
# 815         Dubai International Cricket Stadium               Delhi Capitals
#
#                            team2                  toss_winner toss_decision  \
# 0          Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1            Chennai Super Kings          Chennai Super Kings           bat
# 2               Rajasthan Royals             Rajasthan Royals           bat
# 3    Royal Challengers Bangalore               Mumbai Indians           bat
# 4                Deccan Chargers              Deccan Chargers           bat
# ..                           ...                          ...           ...
# 811               Mumbai Indians               Mumbai Indians         field
# 812               Delhi Capitals               Delhi Capitals         field
# 813          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 814          Sunrisers Hyderabad               Delhi Capitals           bat
# 815               Mumbai Indians               Delhi Capitals           bat
#
#                           winner   result      umpire1         umpire2  Year
# 0          Kolkata Knight Riders     runs    Asad Rauf     RE Koertzen  2008
# 1            Chennai Super Kings     runs    MR Benson      SL Shastri  2008
# 2               Delhi Daredevils  wickets    Aleem Dar  GA Pratapkumar  2008
# 3    Royal Challengers Bangalore  wickets     SJ Davis       DJ Harper  2008
# 4          Kolkata Knight Riders  wickets    BF Bowden     K Hariharan  2008
# ..                           ...      ...          ...             ...   ...
# 811  Royal Challengers Bangalore      tie  Nitin Menon      PR Reiffel  2020
# 812               Mumbai Indians     runs  CB Gaffaney     Nitin Menon  2020
# 813          Sunrisers Hyderabad  wickets   PR Reiffel          S Ravi  2020
# 814               Delhi Capitals     runs   PR Reiffel          S Ravi  2020
# 815               Mumbai Indians  wickets  CB Gaffaney     Nitin Menon  2020
#
# [815 rows x 14 columns]

# %%
def Yearwise_matches( year,season):
    name = []
    for i in df1['Year']:
        if i == year:
            name.append(i)
    print("Number of matches in ", year, ",i.e, season",season,":",len(name))

# %%
df1['Year'].max()
# Out:
# 2020

# %%
print("*"*100)
Yearwise_matches(2008,1)
print("-"*100)
Yearwise_matches(2009,2)
print("-"*100)
Yearwise_matches(2010,3)
print("-"*100)
Yearwise_matches(2011,4)
print("-"*100)
Yearwise_matches(2012,5)
print("-"*100)
Yearwise_matches(2013,6)
print("-"*100)
Yearwise_matches(2014,7)
print("-"*100)
Yearwise_matches(2015,8)
print("-"*100)
Yearwise_matches(2016,9)
print("-"*100)
Yearwise_matches(2017,10)
print("-"*100)
Yearwise_matches(2018,11)
print("-"*100)
Yearwise_matches(2019,12)
print("-"*100)
Yearwise_matches(2020,13)
print("*"*100)
# Out:
# ****************************************************************************************************
# Number of matches in  2008 ,i.e, season 1 : 58
# ----------------------------------------------------------------------------------------------------
# Number of matches in  2009 ,i.e, season 2 : 57
# ----------------------------------------------------------------------------------------------------
# Number of matches in  2010 ,i.e, season 3 : 60
# ----------------------------------------------------------------------------------------------------
# Number of matches in  2011 ,i.e, season 4 : 72
# ----------------------------------------------------------------------------------------------------
# Number of matches in  2012 ,i.e, season 5 : 74
# ----------------------------------------------------------------------------------------------------
# Number of matches in  2013 ,i.e, season 6 : 76
# ----------------------------------------------------------------------------------------------------
# Number of matches in  2014 ,i.e, season 7 : 60
# ----------------------------------------------------------------------------------------------------
# Number of matches in  2015 ,i.e, season 8 : 59
# ----------------------------------------------------------------------------------------------------
# Number of matches in  2016 ,i.e, season 9 : 60
# ----------------------------------------------------------------------------------------------------
# Number of matches in  2017 ,i.e, season 10 : 59
# ----------------------------------------------------------------------------------------------------
# Number of matches in  2018 ,i.e, season 11 : 60
# ----------------------------------------------------------------------------------------------------
# Number of matches in  2019 ,i.e, season 12 : 60
# ----------------------------------------------------------------------------------------------------
# Number of matches in  2020 ,i.e, season 13 : 60
# ****************************************************************************************************

# %% [markdown]
# ## 2] How many runs were scored in each season?

# %%
# Merge datasets
merged_df = pd.merge(df, df1, on='id')
merged_df
# Out:
#              id  inning  over  ball      batsman  non_striker  \
# 0        335982       1     6     5   RT Ponting  BB McCullum
# 1        335982       1     6     6  BB McCullum   RT Ponting
# 2        335982       1     7     1  BB McCullum   RT Ponting
# 3        335982       1     7     2  BB McCullum   RT Ponting
# 4        335982       1     7     3   RT Ponting  BB McCullum
# ...         ...     ...   ...   ...          ...          ...
# 193400  1237181       1    12     5      RR Pant      SS Iyer
# 193401  1237181       1    12     6      RR Pant      SS Iyer
# 193402  1237181       1    13     1      RR Pant      SS Iyer
# 193403  1237181       1    13     2      RR Pant      SS Iyer
# 193404  1237181       1    13     3      SS Iyer      RR Pant
#
#                  bowler  batsman_runs  extra_runs  total_runs  ...  \
# 0             AA Noffke             1           0           1  ...
# 1             AA Noffke             1           0           1  ...
# 2                Z Khan             0           0           0  ...
# 3                Z Khan             1           0           1  ...
# 4                Z Khan             1           0           1  ...
# ...                 ...           ...         ...         ...  ...
# 193400  NM Coulter-Nile             0           0           0  ...
# 193401  NM Coulter-Nile             1           0           1  ...
# 193402        KH Pandya             0           1           1  ...
# 193403        KH Pandya             1           0           1  ...
# 193404        KH Pandya             1           0           1  ...
#
#                                       venue                        team1  \
# 0                     M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1                     M Chinnaswamy Stadium  Royal Challengers Bangalore
# 2                     M Chinnaswamy Stadium  Royal Challengers Bangalore
# 3                     M Chinnaswamy Stadium  Royal Challengers Bangalore
# 4                     M Chinnaswamy Stadium  Royal Challengers Bangalore
# ...                                     ...                          ...
# 193400  Dubai International Cricket Stadium               Delhi Capitals
# 193401  Dubai International Cricket Stadium               Delhi Capitals
# 193402  Dubai International Cricket Stadium               Delhi Capitals
# 193403  Dubai International Cricket Stadium               Delhi Capitals
# 193404  Dubai International Cricket Stadium               Delhi Capitals
#
#                         team2                  toss_winner toss_decision  \
# 0       Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1       Kolkata Knight Riders  Royal Challengers Bangalore         field
# 2       Kolkata Knight Riders  Royal Challengers Bangalore         field
# 3       Kolkata Knight Riders  Royal Challengers Bangalore         field
# 4       Kolkata Knight Riders  Royal Challengers Bangalore         field
# ...                       ...                          ...           ...
# 193400         Mumbai Indians               Delhi Capitals           bat
# 193401         Mumbai Indians               Delhi Capitals           bat
# 193402         Mumbai Indians               Delhi Capitals           bat
# 193403         Mumbai Indians               Delhi Capitals           bat
# 193404         Mumbai Indians               Delhi Capitals           bat
#
#                        winner   result      umpire1      umpire2  Year
# 0       Kolkata Knight Riders     runs    Asad Rauf  RE Koertzen  2008
# 1       Kolkata Knight Riders     runs    Asad Rauf  RE Koertzen  2008
# 2       Kolkata Knight Riders     runs    Asad Rauf  RE Koertzen  2008
# 3       Kolkata Knight Riders     runs    Asad Rauf  RE Koertzen  2008
# 4       Kolkata Knight Riders     runs    Asad Rauf  RE Koertzen  2008
# ...                       ...      ...          ...          ...   ...
# 193400         Mumbai Indians  wickets  CB Gaffaney  Nitin Menon  2020
# 193401         Mumbai Indians  wickets  CB Gaffaney  Nitin Menon  2020
# 193402         Mumbai Indians  wickets  CB Gaffaney  Nitin Menon  2020
# 193403         Mumbai Indians  wickets  CB Gaffaney  Nitin Menon  2020
# 193404         Mumbai Indians  wickets  CB Gaffaney  Nitin Menon  2020
#
# [193405 rows x 27 columns]

# %%
runs_per_season = merged_df.groupby('Year')['total_runs'].sum()     #grouping and adding total runs based on match year
runs = runs_per_season.tolist()
yr=2008
print('--------Runs per season--------')
for i in runs:
    print(yr,':',i)
    print('-------------')
    yr+=1
# Out:
# --------Runs per season--------
# 2008 : 17937
# -------------
# 2009 : 16320
# -------------
# 2010 : 18864
# -------------
# 2011 : 21098
# -------------
# 2012 : 22453
# -------------
# 2013 : 22541
# -------------
# 2014 : 18909
# -------------
# 2015 : 18332
# -------------
# 2016 : 18862
# -------------
# 2017 : 18769
# -------------
# 2018 : 19901
# -------------
# 2019 : 19400
# -------------
# 2020 : 19352
# -------------

# %% [markdown]
# ## 3] What were the runs scored per match in different seasons?

# %%
runs_per_match = merged_df.groupby('id')['total_runs'].sum()
run = runs_per_match.tolist()
len(run)
# Out:
# 815

# %%
df1['runs_per_match']=run

# %%
df1.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
#
#                         winner   result    umpire1         umpire2  Year  \
# 0        Kolkata Knight Riders     runs  Asad Rauf     RE Koertzen  2008
# 1          Chennai Super Kings     runs  MR Benson      SL Shastri  2008
# 2             Delhi Daredevils  wickets  Aleem Dar  GA Pratapkumar  2008
# 3  Royal Challengers Bangalore  wickets   SJ Davis       DJ Harper  2008
# 4        Kolkata Knight Riders  wickets  BF Bowden     K Hariharan  2008
#
#    runs_per_match
# 0             304
# 1             447
# 2             261
# 3             331
# 4             222

# %%
data = df1.values

# %%
data.shape
# Out:
# (815, 15)

# %%
def match_per_season(y:int):                  #function to print number of matches and runs scored in each matches as per season
    print('---- Year: ',y,'----')
    print('match_id : no_of_runs')
    print('----------------')
    for i in data:
        if i[-2]==y:
            print( i[0], '  :', i[-1])
            print('----------------')

# %%
match_per_season(2008)
# Out:
# ---- Year:  2008 ----
# match_id : no_of_runs
# ----------------
# 335982   : 304
# ----------------
# 335983   : 447
# ----------------
# 335984   : 261
# ----------------
# 335985   : 331
# ----------------
# 335986   : 222
# ----------------
# 335987   : 334
# ----------------
# 335988   : 285
# ----------------
# 335989   : 410
# ----------------
# 335990   : 431
# ----------------
# 335991   : 298
# ----------------
# 335992   : 273
# ----------------
# 335993   : 299
# ----------------
# 335994   : 309
# ----------------
# 335995   : 320
# ----------------
# 335996   : 343
# ----------------
# 335997   : 275
# ----------------
# 335998   : 372
# ----------------
# 335999   : 331
# ----------------
# 336000   : 347
# ----------------
# 336001   : 341
# ----------------
# 336002   : 336
# ----------------
# 336003   : 347
# ----------------
# 336004   : 295
# ----------------
# 336005   : 219
# ----------------
# 336006   : 253
# ----------------
# 336007   : 292
# ----------------
# 336008   : 207
# ----------------
# 336009   : 375
# ----------------
# 336010   : 253
# ----------------
# 336011   : 281
# ----------------
# 336012   : 248
# ----------------
# 336013   : 344
# ----------------
# 336014   : 385
# ----------------
# 336015   : 315
# ----------------
# 336016   : 287
# ----------------
# 336017   : 243
# ----------------
# 336018   : 314
# ----------------
# 336019   : 401
# ----------------
# 336020   : 376
# ----------------
# 336021   : 135
# ----------------
# 336022   : 212
# ----------------
# 336023   : 329
# ----------------
# 336024   : 331
# ----------------
# 336025   : 204
# ----------------
# 336026   : 312
# ----------------
# 336027   : 297
# ----------------
# 336028   : 377
# ----------------
# 336029   : 238
# ----------------
# 336031   : 353
# ----------------
# 336032   : 355
# ----------------
# 336033   : 412
# ----------------
# 336034   : 309
# ----------------
# 336035   : 349
# ----------------
# 336036   : 291
# ----------------
# 336037   : 295
# ----------------
# 336038   : 279
# ----------------
# 336039   : 228
# ----------------
# 336040   : 327
# ----------------

# %%
match_per_season(2009)
# Out:
# ---- Year:  2009 ----
# match_id : no_of_runs
# ----------------
# 392181   : 311
# ----------------
# 392182   : 191
# ----------------
# 392183   : 162
# ----------------
# 392184   : 205
# ----------------
# 392185   : 266
# ----------------
# 392186   : 237
# ----------------
# 392188   : 344
# ----------------
# 392189   : 369
# ----------------
# 392190   : 300
# ----------------
# 392191   : 341
# ----------------
# 392192   : 324
# ----------------
# 392194   : 299
# ----------------
# 392195   : 251
# ----------------
# 392196   : 334
# ----------------
# 392197   : 282
# ----------------
# 392198   : 290
# ----------------
# 392199   : 282
# ----------------
# 392200   : 235
# ----------------
# 392201   : 298
# ----------------
# 392202   : 290
# ----------------
# 392203   : 287
# ----------------
# 392204   : 282
# ----------------
# 392205   : 283
# ----------------
# 392206   : 308
# ----------------
# 392207   : 307
# ----------------
# 392208   : 299
# ----------------
# 392209   : 278
# ----------------
# 392210   : 344
# ----------------
# 392211   : 311
# ----------------
# 392212   : 271
# ----------------
# 392213   : 212
# ----------------
# 392214   : 359
# ----------------
# 392215   : 234
# ----------------
# 392216   : 337
# ----------------
# 392217   : 281
# ----------------
# 392218   : 298
# ----------------
# 392219   : 248
# ----------------
# 392220   : 279
# ----------------
# 392221   : 349
# ----------------
# 392222   : 241
# ----------------
# 392223   : 334
# ----------------
# 392224   : 261
# ----------------
# 392225   : 288
# ----------------
# 392226   : 243
# ----------------
# 392227   : 298
# ----------------
# 392228   : 326
# ----------------
# 392229   : 267
# ----------------
# 392230   : 286
# ----------------
# 392231   : 377
# ----------------
# 392232   : 269
# ----------------
# 392233   : 203
# ----------------
# 392234   : 208
# ----------------
# 392235   : 331
# ----------------
# 392236   : 328
# ----------------
# 392237   : 307
# ----------------
# 392238   : 295
# ----------------
# 392239   : 280
# ----------------

# %%
match_per_season(2010)
# Out:
# ---- Year:  2010 ----
# match_id : no_of_runs
# ----------------
# 419106   : 311
# ----------------
# 419107   : 420
# ----------------
# 419108   : 288
# ----------------
# 419109   : 271
# ----------------
# 419110   : 349
# ----------------
# 419111   : 283
# ----------------
# 419112   : 407
# ----------------
# 419113   : 273
# ----------------
# 419114   : 338
# ----------------
# 419115   : 185
# ----------------
# 419116   : 375
# ----------------
# 419117   : 334
# ----------------
# 419118   : 302
# ----------------
# 419119   : 306
# ----------------
# 419120   : 332
# ----------------
# 419121   : 272
# ----------------
# 419122   : 311
# ----------------
# 419123   : 306
# ----------------
# 419124   : 335
# ----------------
# 419125   : 361
# ----------------
# 419126   : 299
# ----------------
# 419127   : 327
# ----------------
# 419128   : 349
# ----------------
# 419129   : 337
# ----------------
# 419130   : 303
# ----------------
# 419131   : 314
# ----------------
# 419132   : 327
# ----------------
# 419133   : 323
# ----------------
# 419134   : 309
# ----------------
# 419135   : 338
# ----------------
# 419136   : 365
# ----------------
# 419137   : 469
# ----------------
# 419138   : 293
# ----------------
# 419139   : 404
# ----------------
# 419140   : 331
# ----------------
# 419141   : 316
# ----------------
# 419142   : 306
# ----------------
# 419143   : 310
# ----------------
# 419144   : 348
# ----------------
# 419145   : 370
# ----------------
# 419146   : 312
# ----------------
# 419147   : 277
# ----------------
# 419148   : 322
# ----------------
# 419149   : 223
# ----------------
# 419150   : 311
# ----------------
# 419151   : 289
# ----------------
# 419152   : 327
# ----------------
# 419153   : 282
# ----------------
# 419154   : 262
# ----------------
# 419155   : 225
# ----------------
# 419156   : 352
# ----------------
# 419157   : 325
# ----------------
# 419158   : 265
# ----------------
# 419159   : 387
# ----------------
# 419160   : 279
# ----------------
# 419161   : 268
# ----------------
# 419162   : 333
# ----------------
# 419163   : 246
# ----------------
# 419164   : 168
# ----------------
# 419165   : 314
# ----------------

# %%
match_per_season(2011)
# Out:
# ---- Year:  2011 ----
# match_id : no_of_runs
# ----------------
# 501198   : 304
# ----------------
# 501199   : 278
# ----------------
# 501200   : 323
# ----------------
# 501201   : 194
# ----------------
# 501202   : 225
# ----------------
# 501203   : 317
# ----------------
# 501204   : 303
# ----------------
# 501205   : 283
# ----------------
# 501206   : 381
# ----------------
# 501207   : 299
# ----------------
# 501208   : 317
# ----------------
# 501209   : 319
# ----------------
# 501210   : 366
# ----------------
# 501211   : 345
# ----------------
# 501212   : 331
# ----------------
# 501213   : 377
# ----------------
# 501214   : 166
# ----------------
# 501215   : 266
# ----------------
# 501216   : 320
# ----------------
# 501218   : 242
# ----------------
# 501219   : 258
# ----------------
# 501220   : 342
# ----------------
# 501221   : 320
# ----------------
# 501222   : 346
# ----------------
# 501223   : 433
# ----------------
# 501224   : 307
# ----------------
# 501225   : 220
# ----------------
# 501226   : 259
# ----------------
# 501227   : 321
# ----------------
# 501228   : 286
# ----------------
# 501229   : 203
# ----------------
# 501230   : 279
# ----------------
# 501231   : 189
# ----------------
# 501232   : 336
# ----------------
# 501233   : 276
# ----------------
# 501234   : 239
# ----------------
# 501235   : 287
# ----------------
# 501236   : 311
# ----------------
# 501237   : 295
# ----------------
# 501238   : 281
# ----------------
# 501239   : 318
# ----------------
# 501240   : 296
# ----------------
# 501241   : 299
# ----------------
# 501242   : 295
# ----------------
# 501243   : 354
# ----------------
# 501244   : 325
# ----------------
# 501245   : 175
# ----------------
# 501246   : 324
# ----------------
# 501247   : 253
# ----------------
# 501248   : 239
# ----------------
# 501249   : 329
# ----------------
# 501250   : 273
# ----------------
# 501251   : 250
# ----------------
# 501252   : 297
# ----------------
# 501253   : 334
# ----------------
# 501254   : 359
# ----------------
# 501255   : 194
# ----------------
# 501256   : 260
# ----------------
# 501257   : 311
# ----------------
# 501258   : 195
# ----------------
# 501259   : 274
# ----------------
# 501260   : 353
# ----------------
# 501261   : 293
# ----------------
# 501262   : 237
# ----------------
# 501263   : 267
# ----------------
# 501264   : 314
# ----------------
# 501266   : 257
# ----------------
# 501267   : 353
# ----------------
# 501268   : 352
# ----------------
# 501269   : 295
# ----------------
# 501270   : 327
# ----------------
# 501271   : 352
# ----------------

# %%
match_per_season(2012)
# Out:
# ---- Year:  2012 ----
# match_id : no_of_runs
# ----------------
# 548306   : 227
# ----------------
# 548307   : 197
# ----------------
# 548308   : 230
# ----------------
# 548309   : 351
# ----------------
# 548310   : 294
# ----------------
# 548311   : 312
# ----------------
# 548312   : 306
# ----------------
# 548313   : 310
# ----------------
# 548314   : 280
# ----------------
# 548315   : 288
# ----------------
# 548316   : 221
# ----------------
# 548317   : 367
# ----------------
# 548318   : 413
# ----------------
# 548319   : 231
# ----------------
# 548320   : 268
# ----------------
# 548321   : 319
# ----------------
# 548322   : 311
# ----------------
# 548323   : 266
# ----------------
# 548324   : 331
# ----------------
# 548325   : 185
# ----------------
# 548326   : 393
# ----------------
# 548327   : 368
# ----------------
# 548328   : 251
# ----------------
# 548329   : 380
# ----------------
# 548330   : 315
# ----------------
# 548331   : 329
# ----------------
# 548332   : 293
# ----------------
# 548333   : 364
# ----------------
# 548334   : 327
# ----------------
# 548335   : 253
# ----------------
# 548336   : 332
# ----------------
# 548337   : 294
# ----------------
# 548339   : 339
# ----------------
# 548341   : 336
# ----------------
# 548342   : 377
# ----------------
# 548343   : 305
# ----------------
# 548344   : 333
# ----------------
# 548345   : 303
# ----------------
# 548346   : 201
# ----------------
# 548347   : 279
# ----------------
# 548348   : 359
# ----------------
# 548349   : 285
# ----------------
# 548350   : 321
# ----------------
# 548351   : 239
# ----------------
# 548352   : 310
# ----------------
# 548353   : 293
# ----------------
# 548354   : 311
# ----------------
# 548355   : 347
# ----------------
# 548356   : 366
# ----------------
# 548357   : 307
# ----------------
# 548358   : 251
# ----------------
# 548359   : 315
# ----------------
# 548360   : 283
# ----------------
# 548361   : 253
# ----------------
# 548362   : 311
# ----------------
# 548363   : 337
# ----------------
# 548364   : 229
# ----------------
# 548365   : 295
# ----------------
# 548366   : 384
# ----------------
# 548367   : 344
# ----------------
# 548368   : 318
# ----------------
# 548369   : 276
# ----------------
# 548370   : 248
# ----------------
# 548371   : 243
# ----------------
# 548372   : 409
# ----------------
# 548373   : 254
# ----------------
# 548374   : 286
# ----------------
# 548375   : 238
# ----------------
# 548376   : 255
# ----------------
# 548377   : 325
# ----------------
# 548378   : 306
# ----------------
# 548379   : 336
# ----------------
# 548380   : 358
# ----------------
# 548381   : 382
# ----------------

# %%
match_per_season(2013)
# Out:
# ---- Year:  2013 ----
# match_id : no_of_runs
# ----------------
# 597998   : 257
# ----------------
# 597999   : 310
# ----------------
# 598000   : 230
# ----------------
# 598001   : 325
# ----------------
# 598002   : 287
# ----------------
# 598003   : 199
# ----------------
# 598004   : 260
# ----------------
# 598005   : 269
# ----------------
# 598006   : 374
# ----------------
# 598007   : 277
# ----------------
# 598008   : 312
# ----------------
# 598009   : 293
# ----------------
# 598010   : 229
# ----------------
# 598011   : 325
# ----------------
# 598012   : 331
# ----------------
# 598013   : 312
# ----------------
# 598014   : 250
# ----------------
# 598015   : 294
# ----------------
# 598016   : 310
# ----------------
# 598017   : 304
# ----------------
# 598018   : 227
# ----------------
# 598019   : 271
# ----------------
# 598020   : 252
# ----------------
# 598021   : 250
# ----------------
# 598022   : 243
# ----------------
# 598023   : 240
# ----------------
# 598024   : 326
# ----------------
# 598025   : 371
# ----------------
# 598026   : 371
# ----------------
# 598027   : 396
# ----------------
# 598028   : 335
# ----------------
# 598029   : 321
# ----------------
# 598030   : 319
# ----------------
# 598031   : 299
# ----------------
# 598032   : 290
# ----------------
# 598033   : 330
# ----------------
# 598034   : 386
# ----------------
# 598035   : 313
# ----------------
# 598036   : 344
# ----------------
# 598037   : 344
# ----------------
# 598038   : 291
# ----------------
# 598039   : 259
# ----------------
# 598040   : 273
# ----------------
# 598041   : 357
# ----------------
# 598042   : 357
# ----------------
# 598043   : 265
# ----------------
# 598044   : 161
# ----------------
# 598045   : 350
# ----------------
# 598046   : 218
# ----------------
# 598047   : 360
# ----------------
# 598048   : 323
# ----------------
# 598049   : 309
# ----------------
# 598050   : 275
# ----------------
# 598051   : 369
# ----------------
# 598052   : 292
# ----------------
# 598053   : 258
# ----------------
# 598054   : 362
# ----------------
# 598055   : 228
# ----------------
# 598056   : 270
# ----------------
# 598057   : 231
# ----------------
# 598058   : 285
# ----------------
# 598059   : 241
# ----------------
# 598060   : 362
# ----------------
# 598061   : 333
# ----------------
# 598062   : 303
# ----------------
# 598063   : 318
# ----------------
# 598064   : 384
# ----------------
# 598065   : 249
# ----------------
# 598066   : 316
# ----------------
# 598067   : 306
# ----------------
# 598068   : 188
# ----------------
# 598069   : 262
# ----------------
# 598070   : 336
# ----------------
# 598071   : 267
# ----------------
# 598072   : 334
# ----------------
# 598073   : 273
# ----------------

# %%
match_per_season(2014)
# Out:
# ---- Year:  2014 ----
# match_id : no_of_runs
# ----------------
# 729279   : 285
# ----------------
# 729281   : 291
# ----------------
# 729283   : 411
# ----------------
# 729285   : 268
# ----------------
# 729287   : 231
# ----------------
# 729289   : 333
# ----------------
# 729291   : 384
# ----------------
# 729293   : 261
# ----------------
# 729295   : 314
# ----------------
# 729297   : 273
# ----------------
# 729299   : 298
# ----------------
# 729301   : 364
# ----------------
# 729303   : 283
# ----------------
# 729305   : 141
# ----------------
# 729307   : 241
# ----------------
# 729309   : 251
# ----------------
# 729311   : 291
# ----------------
# 729313   : 251
# ----------------
# 729315   : 304
# ----------------
# 729317   : 329
# ----------------
# 733971   : 262
# ----------------
# 733973   : 338
# ----------------
# 733975   : 308
# ----------------
# 733977   : 313
# ----------------
# 733979   : 330
# ----------------
# 733981   : 359
# ----------------
# 733983   : 355
# ----------------
# 733985   : 321
# ----------------
# 733987   : 418
# ----------------
# 733989   : 236
# ----------------
# 733991   : 364
# ----------------
# 733993   : 187
# ----------------
# 733995   : 317
# ----------------
# 733997   : 299
# ----------------
# 733999   : 381
# ----------------
# 734001   : 317
# ----------------
# 734003   : 297
# ----------------
# 734005   : 356
# ----------------
# 734007   : 416
# ----------------
# 734009   : 283
# ----------------
# 734011   : 340
# ----------------
# 734013   : 280
# ----------------
# 734015   : 288
# ----------------
# 734017   : 331
# ----------------
# 734019   : 329
# ----------------
# 734021   : 321
# ----------------
# 734023   : 310
# ----------------
# 734025   : 315
# ----------------
# 734027   : 360
# ----------------
# 734029   : 374
# ----------------
# 734031   : 331
# ----------------
# 734033   : 342
# ----------------
# 734035   : 314
# ----------------
# 734037   : 321
# ----------------
# 734039   : 234
# ----------------
# 734041   : 384
# ----------------
# 734043   : 298
# ----------------
# 734045   : 349
# ----------------
# 734047   : 428
# ----------------
# 734049   : 399
# ----------------

# %%
match_per_season(2015)
# Out:
# ---- Year:  2015 ----
# match_id : no_of_runs
# ----------------
# 829705   : 338
# ----------------
# 829707   : 299
# ----------------
# 829709   : 298
# ----------------
# 829711   : 373
# ----------------
# 829713   : 356
# ----------------
# 829715   : 370
# ----------------
# 829717   : 336
# ----------------
# 829719   : 338
# ----------------
# 829721   : 329
# ----------------
# 829723   : 334
# ----------------
# 829725   : 334
# ----------------
# 829727   : 258
# ----------------
# 829729   : 372
# ----------------
# 829731   : 330
# ----------------
# 829733   : 314
# ----------------
# 829735   : 313
# ----------------
# 829737   : 400
# ----------------
# 829739   : 293
# ----------------
# 829741   : 382
# ----------------
# 829743   : 277
# ----------------
# 829745   : 335
# ----------------
# 829747   : 343
# ----------------
# 829749   : 264
# ----------------
# 829751   : 294
# ----------------
# 829753   : 287
# ----------------
# 829757   : 194
# ----------------
# 829759   : 280
# ----------------
# 829761   : 329
# ----------------
# 829763   : 200
# ----------------
# 829765   : 266
# ----------------
# 829767   : 237
# ----------------
# 829769   : 366
# ----------------
# 829771   : 226
# ----------------
# 829773   : 362
# ----------------
# 829775   : 321
# ----------------
# 829777   : 364
# ----------------
# 829779   : 272
# ----------------
# 829781   : 299
# ----------------
# 829783   : 305
# ----------------
# 829785   : 314
# ----------------
# 829787   : 395
# ----------------
# 829789   : 317
# ----------------
# 829791   : 367
# ----------------
# 829793   : 320
# ----------------
# 829795   : 431
# ----------------
# 829797   : 302
# ----------------
# 829799   : 365
# ----------------
# 829801   : 239
# ----------------
# 829803   : 190
# ----------------
# 829805   : 337
# ----------------
# 829807   : 218
# ----------------
# 829809   : 264
# ----------------
# 829811   : 389
# ----------------
# 829813   : 189
# ----------------
# 829815   : 227
# ----------------
# 829817   : 349
# ----------------
# 829819   : 289
# ----------------
# 829821   : 279
# ----------------
# 829823   : 363
# ----------------

# %%
match_per_season(2016)
# Out:
# ---- Year:  2016 ----
# match_id : no_of_runs
# ----------------
# 980901   : 247
# ----------------
# 980903   : 197
# ----------------
# 980905   : 323
# ----------------
# 980907   : 409
# ----------------
# 980909   : 375
# ----------------
# 980911   : 327
# ----------------
# 980913   : 224
# ----------------
# 980915   : 288
# ----------------
# 980917   : 290
# ----------------
# 980919   : 305
# ----------------
# 980921   : 383
# ----------------
# 980923   : 287
# ----------------
# 980925   : 279
# ----------------
# 980927   : 341
# ----------------
# 980929   : 272
# ----------------
# 980931   : 357
# ----------------
# 980933   : 318
# ----------------
# 980935   : 289
# ----------------
# 980937   : 362
# ----------------
# 980939   : 322
# ----------------
# 980941   : 353
# ----------------
# 980943   : 212
# ----------------
# 980945   : 343
# ----------------
# 980947   : 352
# ----------------
# 980949   : 391
# ----------------
# 980951   : 345
# ----------------
# 980953   : 373
# ----------------
# 980955   : 285
# ----------------
# 980957   : 320
# ----------------
# 980959   : 374
# ----------------
# 980961   : 299
# ----------------
# 980963   : 321
# ----------------
# 980965   : 328
# ----------------
# 980967   : 255
# ----------------
# 980969   : 386
# ----------------
# 980971   : 353
# ----------------
# 980973   : 269
# ----------------
# 980975   : 322
# ----------------
# 980977   : 349
# ----------------
# 980979   : 270
# ----------------
# 980981   : 304
# ----------------
# 980983   : 296
# ----------------
# 980985   : 251
# ----------------
# 980987   : 352
# ----------------
# 980989   : 169
# ----------------
# 980991   : 359
# ----------------
# 980993   : 332
# ----------------
# 980995   : 369
# ----------------
# 980997   : 197
# ----------------
# 980999   : 331
# ----------------
# 981001   : 249
# ----------------
# 981003   : 319
# ----------------
# 981005   : 345
# ----------------
# 981007   : 345
# ----------------
# 981009   : 320
# ----------------
# 981011   : 277
# ----------------
# 981013   : 317
# ----------------
# 981015   : 302
# ----------------
# 981017   : 325
# ----------------
# 981019   : 408
# ----------------

# %%
match_per_season(2017)
# Out:
# ---- Year:  2017 ----
# match_id : no_of_runs
# ----------------
# 1082591   : 379
# ----------------
# 1082592   : 371
# ----------------
# 1082593   : 367
# ----------------
# 1082594   : 327
# ----------------
# 1082595   : 299
# ----------------
# 1082596   : 275
# ----------------
# 1082597   : 358
# ----------------
# 1082598   : 298
# ----------------
# 1082599   : 313
# ----------------
# 1082600   : 317
# ----------------
# 1082601   : 341
# ----------------
# 1082602   : 287
# ----------------
# 1082603   : 343
# ----------------
# 1082604   : 327
# ----------------
# 1082605   : 325
# ----------------
# 1082606   : 353
# ----------------
# 1082607   : 295
# ----------------
# 1082608   : 337
# ----------------
# 1082609   : 313
# ----------------
# 1082610   : 405
# ----------------
# 1082611   : 367
# ----------------
# 1082612   : 397
# ----------------
# 1082613   : 375
# ----------------
# 1082614   : 270
# ----------------
# 1082615   : 355
# ----------------
# 1082616   : 350
# ----------------
# 1082617   : 180
# ----------------
# 1082618   : 317
# ----------------
# 1082620   : 366
# ----------------
# 1082621   : 269
# ----------------
# 1082622   : 321
# ----------------
# 1082623   : 388
# ----------------
# 1082624   : 253
# ----------------
# 1082625   : 306
# ----------------
# 1082626   : 135
# ----------------
# 1082627   : 370
# ----------------
# 1082628   : 327
# ----------------
# 1082629   : 328
# ----------------
# 1082630   : 374
# ----------------
# 1082631   : 313
# ----------------
# 1082632   : 422
# ----------------
# 1082633   : 257
# ----------------
# 1082634   : 284
# ----------------
# 1082635   : 278
# ----------------
# 1082636   : 317
# ----------------
# 1082637   : 381
# ----------------
# 1082638   : 278
# ----------------
# 1082639   : 320
# ----------------
# 1082640   : 392
# ----------------
# 1082641   : 453
# ----------------
# 1082642   : 329
# ----------------
# 1082643   : 312
# ----------------
# 1082644   : 337
# ----------------
# 1082645   : 151
# ----------------
# 1082646   : 312
# ----------------
# 1082647   : 304
# ----------------
# 1082648   : 176
# ----------------
# 1082649   : 218
# ----------------
# 1082650   : 257
# ----------------

# %%
match_per_season(2018)
# Out:
# ---- Year:  2018 ----
# match_id : no_of_runs
# ----------------
# 1136561   : 334
# ----------------
# 1136562   : 333
# ----------------
# 1136563   : 353
# ----------------
# 1136564   : 252
# ----------------
# 1136565   : 407
# ----------------
# 1136566   : 213
# ----------------
# 1136567   : 298
# ----------------
# 1136568   : 314
# ----------------
# 1136569   : 389
# ----------------
# 1136570   : 277
# ----------------
# 1136571   : 415
# ----------------
# 1136572   : 390
# ----------------
# 1136573   : 329
# ----------------
# 1136574   : 380
# ----------------
# 1136575   : 323
# ----------------
# 1136576   : 371
# ----------------
# 1136577   : 344
# ----------------
# 1136578   : 317
# ----------------
# 1136579   : 350
# ----------------
# 1136580   : 360
# ----------------
# 1136581   : 335
# ----------------
# 1136582   : 282
# ----------------
# 1136583   : 205
# ----------------
# 1136584   : 412
# ----------------
# 1136585   : 251
# ----------------
# 1136586   : 383
# ----------------
# 1136587   : 339
# ----------------
# 1136588   : 291
# ----------------
# 1136589   : 351
# ----------------
# 1136590   : 409
# ----------------
# 1136591   : 320
# ----------------
# 1136592   : 342
# ----------------
# 1136593   : 357
# ----------------
# 1136594   : 350
# ----------------
# 1136595   : 255
# ----------------
# 1136596   : 327
# ----------------
# 1136597   : 349
# ----------------
# 1136598   : 307
# ----------------
# 1136599   : 287
# ----------------
# 1136600   : 301
# ----------------
# 1136601   : 318
# ----------------
# 1136602   : 378
# ----------------
# 1136603   : 353
# ----------------
# 1136604   : 459
# ----------------
# 1136605   : 368
# ----------------
# 1136606   : 359
# ----------------
# 1136607   : 339
# ----------------
# 1136608   : 180
# ----------------
# 1136609   : 287
# ----------------
# 1136610   : 369
# ----------------
# 1136611   : 422
# ----------------
# 1136612   : 290
# ----------------
# 1136613   : 298
# ----------------
# 1136614   : 345
# ----------------
# 1136615   : 337
# ----------------
# 1136616   : 312
# ----------------
# 1136617   : 279
# ----------------
# 1136618   : 313
# ----------------
# 1136619   : 334
# ----------------
# 1136620   : 359
# ----------------

# %%
match_per_season(2019)
# Out:
# ---- Year:  2019 ----
# match_id : no_of_runs
# ----------------
# 1175356   : 141
# ----------------
# 1175357   : 364
# ----------------
# 1175358   : 389
# ----------------
# 1175359   : 354
# ----------------
# 1175360   : 297
# ----------------
# 1175361   : 408
# ----------------
# 1175362   : 368
# ----------------
# 1175363   : 399
# ----------------
# 1175364   : 353
# ----------------
# 1175365   : 370
# ----------------
# 1175366   : 344
# ----------------
# 1175367   : 342
# ----------------
# 1175368   : 318
# ----------------
# 1175369   : 322
# ----------------
# 1175370   : 303
# ----------------
# 1175371   : 260
# ----------------
# 1175372   : 411
# ----------------
# 1178393   : 298
# ----------------
# 1178394   : 232
# ----------------
# 1178395   : 301
# ----------------
# 1178396   : 279
# ----------------
# 1178397   : 301
# ----------------
# 1178398   : 219
# ----------------
# 1178399   : 395
# ----------------
# 1178400   : 306
# ----------------
# 1178401   : 358
# ----------------
# 1178402   : 375
# ----------------
# 1178403   : 347
# ----------------
# 1178404   : 323
# ----------------
# 1178405   : 271
# ----------------
# 1178406   : 343
# ----------------
# 1178407   : 352
# ----------------
# 1178408   : 269
# ----------------
# 1178409   : 296
# ----------------
# 1178410   : 416
# ----------------
# 1178411   : 323
# ----------------
# 1178412   : 329
# ----------------
# 1178413   : 320
# ----------------
# 1178414   : 321
# ----------------
# 1178415   : 384
# ----------------
# 1178416   : 351
# ----------------
# 1178417   : 387
# ----------------
# 1178418   : 352
# ----------------
# 1178419   : 264
# ----------------
# 1178420   : 321
# ----------------
# 1178421   : 358
# ----------------
# 1178422   : 430
# ----------------
# 1178423   : 379
# ----------------
# 1178424   : 103
# ----------------
# 1178425   : 278
# ----------------
# 1178426   : 324
# ----------------
# 1178427   : 368
# ----------------
# 1178428   : 236
# ----------------
# 1178429   : 353
# ----------------
# 1178430   : 343
# ----------------
# 1178431   : 267
# ----------------
# 1181764   : 263
# ----------------
# 1181766   : 327
# ----------------
# 1181767   : 298
# ----------------
# 1181768   : 297
# ----------------

# %%
match_per_season(2020)
# Out:
# ---- Year:  2020 ----
# match_id : no_of_runs
# ----------------
# 1216492   : 328
# ----------------
# 1216493   : 314
# ----------------
# 1216494   : 169
# ----------------
# 1216495   : 300
# ----------------
# 1216496   : 416
# ----------------
# 1216497   : 329
# ----------------
# 1216498   : 240
# ----------------
# 1216499   : 330
# ----------------
# 1216500   : 322
# ----------------
# 1216501   : 324
# ----------------
# 1216502   : 241
# ----------------
# 1216503   : 334
# ----------------
# 1216504   : 311
# ----------------
# 1216505   : 306
# ----------------
# 1216506   : 307
# ----------------
# 1216507   : 321
# ----------------
# 1216508   : 341
# ----------------
# 1216509   : 364
# ----------------
# 1216510   : 315
# ----------------
# 1216511   : 329
# ----------------
# 1216512   : 326
# ----------------
# 1216513   : 359
# ----------------
# 1216514   : 312
# ----------------
# 1216515   : 438
# ----------------
# 1216516   : 321
# ----------------
# 1216517   : 352
# ----------------
# 1216518   : 310
# ----------------
# 1216519   : 333
# ----------------
# 1216520   : 299
# ----------------
# 1216521   : 230
# ----------------
# 1216522   : 356
# ----------------
# 1216523   : 326
# ----------------
# 1216524   : 350
# ----------------
# 1216525   : 301
# ----------------
# 1216526   : 297
# ----------------
# 1216527   : 449
# ----------------
# 1216528   : 314
# ----------------
# 1216529   : 328
# ----------------
# 1216530   : 322
# ----------------
# 1216531   : 348
# ----------------
# 1216532   : 309
# ----------------
# 1216533   : 251
# ----------------
# 1216534   : 316
# ----------------
# 1216535   : 221
# ----------------
# 1216536   : 350
# ----------------
# 1216537   : 371
# ----------------
# 1216538   : 382
# ----------------
# 1216539   : 306
# ----------------
# 1216540   : 306
# ----------------
# 1216541   : 391
# ----------------
# 1216542   : 333
# ----------------
# 1216543   : 309
# ----------------
# 1216544   : 295
# ----------------
# 1216545   : 287
# ----------------
# 1216546   : 331
# ----------------
# 1216547   : 402
# ----------------
# 1237177   : 343
# ----------------
# 1237178   : 263
# ----------------
# 1237180   : 361
# ----------------
# 1237181   : 313
# ----------------

# %% [markdown]
# ## 4] Who has umpired the most?

# %%
#grouping by umpire name and sorting by number of matches umpired in descending order
count=df1.groupby('umpire1').size().sort_values(ascending=False) 
#.idxmax() returns the index (in this case, the name of the umpire) corresponding to the maximum value in the Series, 
# which is the umpire with the highest count.
highest_count = count.idxmax()
print('----------------------')
print(highest_count,':', count.max())
print('----------------------')
# Out:
# ----------------------
# HDPK Dharmasena : 78
# ----------------------

# %%
#grouping by umpire name and sorting by number of matches umpired in descending order
count1=df1.groupby('umpire2').size().sort_values(ascending=False) 
#.idxmax() returns the index (in this case, the name of the umpire) corresponding to the maximum value in the Series, 
# which is the umpire with the highest count.
highest_count1 = count1.idxmax()
print('-------------------')
print(highest_count1,':', count1.max())
print('-------------------')
# Out:
# -------------------
# S Ravi : 84
# -------------------

# %%
print('-'*125)
print('According to the data from both columns (umpire1 and umpire 2) the umpire who had umpired most number of matches is - ')
print('-'*125)
print(highest_count1,':',count1.max(),'(number of matches umpired)')
print('-'*125)
# Out:
# -----------------------------------------------------------------------------------------------------------------------------
# According to the data from both columns (umpire1 and umpire 2) the umpire who had umpired most number of matches is -
# -----------------------------------------------------------------------------------------------------------------------------
# S Ravi : 84 (number of matches umpired)
# -----------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 5] Which team has won the most tosses?

# %%
#grouping by toss_winner name and sorting by number of tosses won in descending order
tcount=df1.groupby('toss_winner').size().sort_values(ascending=False) 
#.idxmax() returns the index (in this case, the name of the team) corresponding to the maximum value in the Series, 
# which is the team with the highest count.
thighest_count = tcount.idxmax()
print('--------------------------------------------------')
print('The team who has won highest number of tosses is -')
print('--------------------------------------------------')
print(thighest_count,':', tcount.max(),'(number of tosses won)')
print('--------------------------------------------------')
# Out:
# --------------------------------------------------
# The team who has won highest number of tosses is -
# --------------------------------------------------
# Mumbai Indians : 106 (number of tosses won)
# --------------------------------------------------

# %% [markdown]
# ## 6] What does team decide after winning the toss?

# %%
data1= np.array(df1)

# %%
data1=data1.tolist()

# %%
count=[]
count1=[]
for i in df1.groupby('toss_winner').size():
     count.append(i)
for i in df1.groupby('toss_decision').size():
     count1.append(i)

# %%
count
# Out:
# [97, 43, 20, 79, 15, 85, 8, 98, 106, 20, 87, 6, 7, 87, 57]

# %%
#groupby('toss winner'): This part of the code groups the DataFrame df2 by the unique values in the 'toss winner' column.
#Each group corresponds to a unique team that has won the toss.|
#['toss decision']: After grouping by the 'toss winner' column, this part selects the 'toss decision' column from each group.
#This column contains information about the decision made by the team that won the toss, whether to bat or field.|
#value_counts(): This function calculates the frequency of each unique value in the selected column.
#In this case, it calculates how many times each value ('Bat' or 'Field') appears in the 'toss decision' column for each group (each team that won the toss).
toss_decision_counts= df1.groupby('toss_winner')['toss_decision'].value_counts()
temp_df = pd.DataFrame(toss_decision_counts)

# %%
temp_df
# Out:
#                                            count
# toss_winner                 toss_decision
# Chennai Super Kings         bat               51
#                             field             46
# Deccan Chargers             bat               24
#                             field             19
# Delhi Capitals              field             13
#                             bat                7
# Delhi Daredevils            field             51
#                             bat               28
# Gujarat Lions               field             14
#                             bat                1
# Kings XI Punjab             field             58
#                             bat               27
# Kochi Tuskers Kerala        field              5
#                             bat                3
# Kolkata Knight Riders       field             64
#                             bat               34
# Mumbai Indians              field             58
#                             bat               48
# Pune Warriors               bat               11
#                             field              9
# Rajasthan Royals            field             53
#                             bat               34
# Rising Pune Supergiant      field              6
# Rising Pune Supergiants     field              4
#                             bat                3
# Royal Challengers Bangalore field             63
#                             bat               24
# Sunrisers Hyderabad         field             33
#                             bat               24

# %% [markdown]
# ## 7] How does the toss decisions vary across seasons?

# %%
toss_decision_season1 = df1.groupby(['Year', 'toss_decision']).size()

# %%
lst = toss_decision_season1.tolist()

bat=[]
c=0
for i in lst:
    if c%2 == 0:
        bat.append(i)
    c=c+1

# %%
bat
# Out:
# [26, 35, 39, 24, 37, 45, 19, 25, 11, 11, 10, 10, 27]

# %%
field=[]
c=0
for i in lst:
    if c%2 != 0:
        field.append(i)
    c=c+1

# %%
field
# Out:
# [32, 22, 21, 48, 37, 31, 41, 34, 49, 48, 50, 50, 33]

# %%
season=[]
for i in df1['Year'].unique():
    season.append(i)
season
# Out:
# [2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

# %%
plt.plot(season,bat,label='bat', color='r',linewidth=2,markersize=8, marker='.')
plt.plot(season,field,label='field',color='blue',linewidth=2,markersize=8, marker='.')
plt.title('Variation in toss decisions across seasons')
plt.xlabel('seasons')
plt.ylabel('count of toss decisions')
plt.legend()
plt.show()

# %% [markdown]
# ## 8] Does winning the toss imply winning the game?

# %%
c = 0
d = 0
for i, row in df1.iterrows():
    if row['toss_winner']==row['winner']:
        c+=1
    if row['toss_winner'] and row['toss_winner']!= row['winner']:
        d+=1
#win_rate_toss_winners = toss_win_match_win / total_toss_wins
win_rate_toss_winners = 418/812    

#Calculate the overall match win rate for teams not winning the toss
win_rate_non_toss_winners = 1 - win_rate_toss_winners

print('---------------------------------------------------------------------------------------------')
print('Toss_win_match_win:',c)
print('win_rate_toss_winners:',win_rate_toss_winners)
print('---------------------------------------------------------------------------------------------')
print('Toss_lose_match_win',d)
print('win_rate_non_toss_winners :',win_rate_non_toss_winners )
print('---------------------------------------------------------------------------------------------')
# Out:
# ---------------------------------------------------------------------------------------------
# Toss_win_match_win: 418
# win_rate_toss_winners: 0.5147783251231527
# ---------------------------------------------------------------------------------------------
# Toss_lose_match_win 397
# win_rate_non_toss_winners : 0.4852216748768473
# ---------------------------------------------------------------------------------------------

# %%
print('------------------------------------------------------------------------------------------------------------------------')
print('As per calculations the win rate of both toss winners and non toss winners is almost the same with a difference of 3%-4%.')
print('So we can safely conclude that winning the toss does not imply winning the game.')
print('But if accurate conclusion or marginal values are concerned then due to number of toss winners winning is higher than number of non toss winners slightly ')
print('------------------------------------------------------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# As per calculations the win rate of both toss winners and non toss winners is almost the same with a difference of 3%-4%.
# So we can safely conclude that winning the toss does not imply winning the game.
# But if accurate conclusion or marginal values are concerned then due to number of toss winners winning is higher than number of non toss winners slightly
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 9] How many times has the chasing team won the match?

# %%
temp1=[]
for i, row in df1.iterrows():            #teams who choose to field and won the match
    if row['toss_winner']==row['winner']:
        if row['toss_decision']=='field':
            temp1.append(row['winner'])
len(temp1)  #273

temp2=[] #187
temp3=[] #132
for i, row in df1.iterrows():
    if row['toss_decision']!=row['winner']:
        if row['toss_decision']=='bat':    #teams who lost the toss toss decision=bat(decided by toss winner) and won
            if row['team1']==row['winner']:    
                temp2.append(row['winner'])
            elif row['team2']==row['winner']:
                temp3.append(row['winner'])
                
total=temp1+temp2+temp3
print('----------------------------------------------------------------')
print('The number of times chasing team had won the match:',len(total))
print('----------------------------------------------------------------')
# Out:
# ----------------------------------------------------------------
# The number of times chasing team had won the match: 592
# ----------------------------------------------------------------

# %% [markdown]
# ## 10] Which all teams had won this tournament?

# %%
won = df1['winner'].unique()
won = won.tolist()

# %%
print('All the teams who had won the tournament are:')
print('-----------------------------------------------')
for i in won:
    print(i)
    print('-----------------------------------------------')
# Out:
# All the teams who had won the tournament are:
# -----------------------------------------------
# Kolkata Knight Riders
# -----------------------------------------------
# Chennai Super Kings
# -----------------------------------------------
# Delhi Daredevils
# -----------------------------------------------
# Royal Challengers Bangalore
# -----------------------------------------------
# Rajasthan Royals
# -----------------------------------------------
# Kings XI Punjab
# -----------------------------------------------
# Deccan Chargers
# -----------------------------------------------
# Mumbai Indians
# -----------------------------------------------
# Pune Warriors
# -----------------------------------------------
# Kochi Tuskers Kerala
# -----------------------------------------------
# Sunrisers Hyderabad
# -----------------------------------------------
# nan
# -----------------------------------------------
# Rising Pune Supergiants
# -----------------------------------------------
# Gujarat Lions
# -----------------------------------------------
# Rising Pune Supergiant
# -----------------------------------------------
# Delhi Capitals
# -----------------------------------------------

# %% [markdown]
# ## 11] Which teams have played most number of matches?

# %%
# Count the occurrences of each team in 'team1' and 'team2' columns
#value_counts() method, which returns a Series containing the counts of unique values in a column.
team1_counts = df1['team1'].value_counts()
team2_counts = df1['team2'].value_counts()

# %%
# Combine the counts for each team
#Combining counts for each team: After counting the occurrences of each team in both columns, the code combines these counts to get the total number of matches each team has played. 
#This is done using the add() method, which adds two Series together.
#team1_counts.add(team2_counts, fill_value=0): This line adds the counts of team occurrences in both 'team1' and 'team2' columns. 
#The fill_value=0 parameter ensures that if a team appears in only one column and not the other, its count is treated as 0.
total_matches = team1_counts.add(team2_counts, fill_value=0)

# %%
# Sort the teams based on the total number of matches played
#sorts the total_matches Series in descending order (ascending=False), so the team with the highest count (i.e., most matches played) appears first.
most_matches_played = total_matches.sort_values(ascending=False)

# %%
print('Teams with the most number of matches played:')
temp1_df = pd.DataFrame(most_matches_played)   
temp1_df
# Out:
# Teams with the most number of matches played:
#                              count
# Mumbai Indians                 203
# Royal Challengers Bangalore    195
# Kolkata Knight Riders          192
# Kings XI Punjab                190
# Chennai Super Kings            178
# Rajasthan Royals               161
# Delhi Daredevils               160
# Sunrisers Hyderabad            124
# Deccan Chargers                 75
# Pune Warriors                   45
# Delhi Capitals                  33
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14

# %% [markdown]
# ## 12] Which team has won the most number of times?

# %%
winner_counts = df1['winner'].value_counts()

# %%
#.idxmax() returns the index (in this case, the name of the team) corresponding to the maximum value in the Series, 
# which is the team with the highest count.
most_win = winner_counts.idxmax()
print('----------------------------------------------------------')
print('The team which has won most number of times is -')
print(most_win,':', winner_counts.max())
print('----------------------------------------------------------')
# Out:
# ----------------------------------------------------------
# The team which has won most number of times is -
# Mumbai Indians : 120
# ----------------------------------------------------------

# %% [markdown]
# ## 13] Which team has the highest winning percentage?

# %%
# Count the occurrences of each team in 'team1' and 'team2' columns
#value_counts() method, which returns a Series containing the counts of unique values in a column.
team1_counts = df1['team1'].value_counts()
team2_counts = df1['team2'].value_counts()

# %%
# Combine the counts for each team
total_matches = team1_counts.add(team2_counts, fill_value=0)

# %%
# Calculate the total number of matches won by each team
win_counts = df1['winner'].value_counts()

# %%
# Calculate the winning percentage for each team
winning_percentage = (win_counts / total_matches) * 100

# %%
#Sorting values of winning percentage in descending order
most_win = winning_percentage.sort_values(ascending=False)

# %%
# Find the team with the highest winning percentage
team_highest_percentage = winning_percentage.idxmax()
highest_percentage = winning_percentage.max()

# %%
print('--------------------------------------------------------------------')
print("Team with the highest winning percentage:", team_highest_percentage)
print("Winning percentage:", highest_percentage)
print('--------------------------------------------------------------------')
# Out:
# --------------------------------------------------------------------
# Team with the highest winning percentage: Rising Pune Supergiant
# Winning percentage: 62.5
# --------------------------------------------------------------------

# %% [markdown]
# ## 14] Is there any lucky venue for a particular team?

# %%
def lucky_venue_for_team(team_name):
#Filtering the dataset: The code filters the dataset df2 to include only matches involving the specified team
#It selects rows where either 'team1' or 'team2' is equal to the specified team name.
    team_matches = df1[(df1['team1'] == team_name) | (df1['team2'] == team_name)]
#-----------------------------------------------------------------------------------------------------------------------------------
#Calculating match counts at each venue: The code calculates the total number of matches played by the specified team at each venue.
#It uses the value_counts() method to count the occurrences of each venue in the filtered dataset.
    venue_counts = team_matches['venue'].value_counts()
#-----------------------------------------------------------------------------------------------------------------------------------------------------------    
#Calculating match win counts at each venue: Similarly, the code calculates the total number of matches won by the specified team at each venue.
#It first filters the dataset to include only matches where the specified team is the winner, and then counts the occurrences of each venue.
    venue_win_counts = team_matches[team_matches['winner'] == team_name]['venue'].value_counts()
#Calculating win percentage at each venue: The code calculates the win percentage for the specified team at each venue by dividing the number of matches won by the total matches played at each venue and multiplying by 100.
    win_percentage = (venue_win_counts / venue_counts) * 100
#Finding the lucky venue: Finally, the code finds the venue with the highest win percentage for the specified team using the idxmax() method, which returns the index (venue name) corresponding to the maximum value in the Series.
    lucky_venue = win_percentage.idxmax()
#It also retrieves the highest win percentage using the max() method.
    highest_win_percentage = win_percentage.max()
#Printing the result
    print("Lucky venue for", team_name, ":", lucky_venue)
    print("Win percentage at", lucky_venue, ":", highest_win_percentage)

# %%
lst=df1['team1'].unique().tolist()

# %%
lst
# Out:
# ['Royal Challengers Bangalore',
#  'Kings XI Punjab',
#  'Delhi Daredevils',
#  'Mumbai Indians',
#  'Kolkata Knight Riders',
#  'Rajasthan Royals',
#  'Deccan Chargers',
#  'Chennai Super Kings',
#  'Kochi Tuskers Kerala',
#  'Pune Warriors',
#  'Sunrisers Hyderabad',
#  'Gujarat Lions',
#  'Rising Pune Supergiants',
#  'Rising Pune Supergiant',
#  'Delhi Capitals']

# %%
for team_name in lst:
    print('-------------------------------------------------------------------------------------------------')
    lucky_venue_for_team(team_name)
print('--------------------------------------------------------------------------------------------------')
# Out:
# -------------------------------------------------------------------------------------------------
# Lucky venue for Royal Challengers Bangalore : Brabourne Stadium
# Win percentage at Brabourne Stadium : 100.0
# -------------------------------------------------------------------------------------------------
# Lucky venue for Kings XI Punjab : De Beers Diamond Oval
# Win percentage at De Beers Diamond Oval : 100.0
# -------------------------------------------------------------------------------------------------
# Lucky venue for Delhi Daredevils : Buffalo Park
# Win percentage at Buffalo Park : 100.0
# -------------------------------------------------------------------------------------------------
# Lucky venue for Mumbai Indians : Holkar Cricket Stadium
# Win percentage at Holkar Cricket Stadium : 100.0
# -------------------------------------------------------------------------------------------------
# Lucky venue for Kolkata Knight Riders : Barabati Stadium
# Win percentage at Barabati Stadium : 100.0
# -------------------------------------------------------------------------------------------------
# Lucky venue for Rajasthan Royals : Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium
# Win percentage at Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium : 100.0
# -------------------------------------------------------------------------------------------------
# Lucky venue for Deccan Chargers : Himachal Pradesh Cricket Association Stadium
# Win percentage at Himachal Pradesh Cricket Association Stadium : 100.0
# -------------------------------------------------------------------------------------------------
# Lucky venue for Chennai Super Kings : Buffalo Park
# Win percentage at Buffalo Park : 100.0
# -------------------------------------------------------------------------------------------------
# Lucky venue for Kochi Tuskers Kerala : Eden Gardens
# Win percentage at Eden Gardens : 100.0
# -------------------------------------------------------------------------------------------------
# Lucky venue for Pune Warriors : Feroz Shah Kotla
# Win percentage at Feroz Shah Kotla : 100.0
# -------------------------------------------------------------------------------------------------
# Lucky venue for Sunrisers Hyderabad : Brabourne Stadium
# Win percentage at Brabourne Stadium : 100.0
# -------------------------------------------------------------------------------------------------
# Lucky venue for Gujarat Lions : Eden Gardens
# Win percentage at Eden Gardens : 100.0
# -------------------------------------------------------------------------------------------------
# Lucky venue for Rising Pune Supergiants : Feroz Shah Kotla
# Win percentage at Feroz Shah Kotla : 100.0
# -------------------------------------------------------------------------------------------------
# Lucky venue for Rising Pune Supergiant : Eden Gardens
# Win percentage at Eden Gardens : 100.0
# -------------------------------------------------------------------------------------------------
# Lucky venue for Delhi Capitals : Eden Gardens
# Win percentage at Eden Gardens : 100.0
# --------------------------------------------------------------------------------------------------

# %% [markdown]
# ## 15] Innings wise comparison between  teams

# %%
grouped_data = df.groupby(['inning', 'batting_team'])

# Step 2: Calculate Metrics
innings_comparison = grouped_data.agg({
    #we calculate the total runs scored by each team in each inning using the agg() function, specifying that we want to sum the 'total_runs' column.
    'total_runs': 'sum'  # Total runs scored
}).reset_index()

# %%
innings_comparison
# Out:
#     inning                 batting_team  total_runs
# 0        1          Chennai Super Kings       15344
# 1        1              Deccan Chargers        6765
# 2        1               Delhi Capitals        2860
# 3        1             Delhi Daredevils       11247
# 4        1                Gujarat Lions        2267
# 5        1              Kings XI Punjab       15710
# 6        1         Kochi Tuskers Kerala        1009
# 7        1        Kolkata Knight Riders       14842
# 8        1               Mumbai Indians       18338
# 9        1                Pune Warriors        2973
# 10       1             Rajasthan Royals       11236
# 11       1       Rising Pune Supergiant        1304
# 12       1      Rising Pune Supergiants        1123
# 13       1  Royal Challengers Bangalore       15774
# 14       1          Sunrisers Hyderabad       11277
# 15       2          Chennai Super Kings       13019
# 16       2              Deccan Chargers        4698
# 17       2               Delhi Capitals        2436
# 18       2             Delhi Daredevils       13038
# 19       2                Gujarat Lions        2589
# 20       2              Kings XI Punjab       14307
# 21       2         Kochi Tuskers Kerala         892
# 22       2        Kolkata Knight Riders       14541
# 23       2               Mumbai Indians       13948
# 24       2                Pune Warriors        3385
# 25       2             Rajasthan Royals       13271
# 26       2       Rising Pune Supergiant        1166
# 27       2      Rising Pune Supergiants         940
# 28       2  Royal Challengers Bangalore       14440
# 29       2          Sunrisers Hyderabad        8055

# %%
# Step 3: Visualize Data
plt.figure(figsize=(10, 6))
for inning in innings_comparison['inning'].unique():
    inning_data = innings_comparison[innings_comparison['inning'] == inning]
    plt.bar(inning_data['batting_team'], inning_data['total_runs'], label=f"Inning {inning}")

plt.xlabel('Batting Team')
plt.ylabel('Total Runs')
plt.title('Bar Graph - Innings-wise Comparison of Total Runs Scored by Each Team')
plt.legend()
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.tight_layout()
plt.show()

# %%
i1=[]
i2=[]
for i,row in innings_comparison.iterrows():
    if(row['inning']==1):
        i1.append(row['total_runs'])

# %%
for i,row in innings_comparison.iterrows():
    if(row['inning']==2):
        i2.append(row['total_runs'])

# %%
teams=[]
for i,row in innings_comparison.iterrows(): 
    teams.append(row['batting_team'])
    if i==14:
        break

# %%
teams
# Out:
# ['Chennai Super Kings',
#  'Deccan Chargers',
#  'Delhi Capitals',
#  'Delhi Daredevils',
#  'Gujarat Lions',
#  'Kings XI Punjab',
#  'Kochi Tuskers Kerala',
#  'Kolkata Knight Riders',
#  'Mumbai Indians',
#  'Pune Warriors',
#  'Rajasthan Royals',
#  'Rising Pune Supergiant',
#  'Rising Pune Supergiants',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad']

# %%
plt.pie(i1)
labels=['Chennai Super Kings',
 'Deccan Chargers',
 'Delhi Capitals',
 'Delhi Daredevils',
 'Gujarat Lions',
 'Kings XI Punjab',
 'Kochi Tuskers Kerala',
 'Kolkata Knight Riders',
 'Mumbai Indians',
 'Pune Warriors',
 'Rajasthan Royals',
 'Rising Pune Supergiant',
 'Rising Pune Supergiants',
 'Royal Challengers Bangalore',
 'Sunrisers Hyderabad']
plt.pie(i1,labels=labels)
plt.title('Pie Chart - Innings-wise Comparison of Total Runs Scored by Each Team (inning 1)')
plt.show()

# %%
plt.pie(i2)
labels=['Chennai Super Kings',
 'Deccan Chargers',
 'Delhi Capitals',
 'Delhi Daredevils',
 'Gujarat Lions',
 'Kings XI Punjab',
 'Kochi Tuskers Kerala',
 'Kolkata Knight Riders',
 'Mumbai Indians',
 'Pune Warriors',
 'Rajasthan Royals',
 'Rising Pune Supergiant',
 'Rising Pune Supergiants',
 'Royal Challengers Bangalore',
 'Sunrisers Hyderabad']
plt.pie(i2,labels=labels)
plt.title('Pie Chart - Innings-wise Comparison of Total Runs Scored by Each Team (inning 2)')
plt.show()

# %%
plt.plot(teams,i1,label='inning 1', color='r',linewidth=2,markersize=8, marker='.')
plt.plot(teams,i2,label='inning 2',color='blue',linewidth=2,markersize=8, marker='.')
plt.title('Pie Chart - Innings-wise Comparison of Total Runs Scored by Each Team')
plt.xlabel('Teams')
plt.ylabel('Runs Scored')
plt.legend()
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 16] Which team has scored the most 200+ scores?

# %%
# Group the dataset by match and batting team, and sum the total runs scored
runs_by_team_per_match = df.groupby(['id', 'batting_team'])['total_runs'].sum().reset_index()
runs_by_team_per_match
# Out:
#            id                 batting_team  total_runs
# 0      335982        Kolkata Knight Riders         222
# 1      335982  Royal Challengers Bangalore          82
# 2      335983          Chennai Super Kings         240
# 3      335983              Kings XI Punjab         207
# 4      335984             Delhi Daredevils         132
# ...       ...                          ...         ...
# 1625  1237178          Sunrisers Hyderabad         132
# 1626  1237180               Delhi Capitals         189
# 1627  1237180          Sunrisers Hyderabad         172
# 1628  1237181               Delhi Capitals         156
# 1629  1237181               Mumbai Indians         157
#
# [1630 rows x 3 columns]

# %%
batting=[]
bowling=[]
batting_runs=[]
bowling_runs=[]
for i,row in runs_by_team_per_match.iterrows():
    if i % 2:
        batting.append(row['batting_team'])
        batting_runs.append(row['total_runs'])
    else :
        bowling.append(row['batting_team'])
        bowling_runs.append(row['total_runs'])

# %%
df1['batting_team']=batting
df1['batting_team_runs']=batting_runs
df1['bowling_team']=bowling
df1['bowling_team_runs']=bowling_runs

# %%
temp1=[]
temp2=[]
for i,row in df1.iterrows():
    if row['batting_team_runs'] >= 200 :
        temp1.append([row['batting_team'], row['batting_team_runs']])
        
for i,row in df1.iterrows():
    if row['bowling_team_runs'] >= 200 :
        temp2.append([row['bowling_team'], row['bowling_team_runs']])

# %%
temp_1=pd.DataFrame(temp1, columns =['batting_team','batting_team_runs'])
temp_2=pd.DataFrame(temp2, columns =['bowling_team','bowling_team_runs'])

# %%
temp1_df = temp_1['batting_team'].value_counts()

# %%
temp2_df = temp_2['bowling_team'].value_counts()

# %%
temp1_df.max(),temp2_df.max()
# Out:
# (13, 11)

# %%
print('-------------------------------------------------------')
print('The team which has scored the most 200+ runs is')
print('-------------------------------------------------------')
print(temp2_df.idxmax(),':',temp2_df.max())
print('-------------------------------------------------------')
# Out:
# -------------------------------------------------------
# The team which has scored the most 200+ runs is
# -------------------------------------------------------
# Kings XI Punjab : 11
# -------------------------------------------------------

# %% [markdown]
# ## 17] Which team has conceded 200+ scores the most?

# %%
lst1 = []
for i, row in df1.iterrows():
    if row['toss_decision'] == 'bat':
        lst1.append(  row['toss_winner'])
    elif row['toss_decision'] == 'field':
        if row['toss_winner']==row['team1']:
            lst1.append(row['team2'])
        elif row['toss_winner']==row['team2']:
            lst1.append(row['team1'])

# %%
df1['batting_team']=lst1

# %%
lst2=[]
for i,row in df1.iterrows():
    if row['batting_team']==row['team1']:
        lst2.append(row['team2'])
    elif row['batting_team']==row['team2']:
        lst2.append(row['team1'])

# %%
df1['bowling_team']=lst2

# %%
temp1=[]
for i,row in df1.iterrows():
    if row['batting_team_runs'] >= 200 :
        temp1.append([row['batting_team'], row['batting_team_runs'], row['bowling_team']])

# %%
temp_df1 = pd.DataFrame(temp1,columns=['batting_team', 'batting_team_runs', 'bowling_team'])

# %%
temp_df1
# Out:
#                    batting_team  batting_team_runs  \
# 0           Chennai Super Kings                207
# 1           Chennai Super Kings                202
# 2               Deccan Chargers                217
# 3         Kolkata Knight Riders                204
# 4              Rajasthan Royals                211
# 5              Rajasthan Royals                211
# 6                Mumbai Indians                208
# 7               Kings XI Punjab                204
# 8                Mumbai Indians                218
# 9           Chennai Super Kings                223
# 10        Kolkata Knight Riders                200
# 11             Delhi Daredevils                202
# 12  Royal Challengers Bangalore                205
# 13          Chennai Super Kings                205
# 14  Royal Challengers Bangalore                208
# 15             Delhi Daredevils                207
# 16          Chennai Super Kings                222
# 17          Chennai Super Kings                200
# 18          Chennai Super Kings                223
# 19          Chennai Super Kings                205
# 20          Sunrisers Hyderabad                211
# 21              Kings XI Punjab                202
# 22          Chennai Super Kings                209
# 23               Mumbai Indians                209
# 24  Royal Challengers Bangalore                200
# 25  Royal Challengers Bangalore                226
# 26          Sunrisers Hyderabad                201
# 27  Royal Challengers Bangalore                235
# 28               Mumbai Indians                202
# 29  Royal Challengers Bangalore                248
# 30               Mumbai Indians                206
# 31  Royal Challengers Bangalore                211
# 32          Sunrisers Hyderabad                208
# 33          Sunrisers Hyderabad                207
# 34  Royal Challengers Bangalore                213
# 35          Sunrisers Hyderabad                207
# 36          Sunrisers Hyderabad                209
# 37                Gujarat Lions                208
# 38               Mumbai Indians                212
# 39              Kings XI Punjab                223
# 40        Kolkata Knight Riders                202
# 41        Kolkata Knight Riders                200
# 42  Royal Challengers Bangalore                205
# 43               Mumbai Indians                210
# 44        Kolkata Knight Riders                245
# 45  Royal Challengers Bangalore                204
# 46        Kolkata Knight Riders                218
# 47             Rajasthan Royals                201
# 48          Sunrisers Hyderabad                231
# 49  Royal Challengers Bangalore                205
# 50  Royal Challengers Bangalore                213
# 51  Royal Challengers Bangalore                202
# 52          Sunrisers Hyderabad                212
# 53             Rajasthan Royals                216
# 54               Delhi Capitals                210
# 55          Sunrisers Hyderabad                219
# 56              Kings XI Punjab                226
# 57          Sunrisers Hyderabad                201
# 58  Royal Challengers Bangalore                201
# 59               Mumbai Indians                200
#
#                    bowling_team
# 0               Kings XI Punjab
# 1                Mumbai Indians
# 2              Rajasthan Royals
# 3               Deccan Chargers
# 4           Chennai Super Kings
# 5               Kings XI Punjab
# 6              Rajasthan Royals
# 7   Royal Challengers Bangalore
# 8              Delhi Daredevils
# 9              Rajasthan Royals
# 10              Kings XI Punjab
# 11              Kings XI Punjab
# 12              Kings XI Punjab
# 13  Royal Challengers Bangalore
# 14          Chennai Super Kings
# 15               Mumbai Indians
# 16             Delhi Daredevils
# 17        Kolkata Knight Riders
# 18          Sunrisers Hyderabad
# 19              Kings XI Punjab
# 20              Kings XI Punjab
# 21          Chennai Super Kings
# 22          Sunrisers Hyderabad
# 23  Royal Challengers Bangalore
# 24             Rajasthan Royals
# 25              Kings XI Punjab
# 26             Rajasthan Royals
# 27               Mumbai Indians
# 28          Chennai Super Kings
# 29                Gujarat Lions
# 30             Delhi Daredevils
# 31              Kings XI Punjab
# 32  Royal Challengers Bangalore
# 33  Royal Challengers Bangalore
# 34                Gujarat Lions
# 35              Kings XI Punjab
# 36        Kolkata Knight Riders
# 37             Delhi Daredevils
# 38             Delhi Daredevils
# 39               Mumbai Indians
# 40          Chennai Super Kings
# 41             Delhi Daredevils
# 42          Chennai Super Kings
# 43        Kolkata Knight Riders
# 44              Kings XI Punjab
# 45          Sunrisers Hyderabad
# 46              Kings XI Punjab
# 47          Sunrisers Hyderabad
# 48  Royal Challengers Bangalore
# 49        Kolkata Knight Riders
# 50        Kolkata Knight Riders
# 51              Kings XI Punjab
# 52              Kings XI Punjab
# 53          Chennai Super Kings
# 54        Kolkata Knight Riders
# 55               Delhi Capitals
# 56             Rajasthan Royals
# 57              Kings XI Punjab
# 58               Mumbai Indians
# 59               Delhi Capitals

# %%
temp_ = temp_df1['bowling_team'].value_counts()

# %%
print('---------------------------------------------------------------------------')
print("Team that has conceded the most 200+ scores:", temp_.idxmax())
print('---------------------------------------------------------------------------')
print("Number of times they conceded 200+ scores:", temp_.max())
print('---------------------------------------------------------------------------')
# Out:
# ---------------------------------------------------------------------------
# Team that has conceded the most 200+ scores: Kings XI Punjab
# ---------------------------------------------------------------------------
# Number of times they conceded 200+ scores: 15
# ---------------------------------------------------------------------------

# %% [markdown]
# ## 18] What was the highest run scored by a team in a single match?

# %%
df1['batting_team_runs'].max()
# Out:
# 248

# %%
df1['bowling_team_runs'].max()
# Out:
# 263

# %%
for i,row in df1.iterrows():
    
        if row['bowling_team_runs']==df1['bowling_team_runs'].max():
            print('-------------------------------------------------------')
            print('The highest run scored by a team in a single match is')
            print('-------------------------------------------------------')
            print(row['winner'],':',df1['bowling_team_runs'].max())
            print('-------------------------------------------------------')
# Out:
# -------------------------------------------------------
# The highest run scored by a team in a single match is
# -------------------------------------------------------
# Kings XI Punjab : 263
# -------------------------------------------------------

# %% [markdown]
# ## 19] Which is the biggest win in terms of run margin?

# %%
#creating a column named run margin in df1
temp1=[]
for i,row in df1.iterrows():
    if row['batting_team_runs'] > row['bowling_team_runs']:
        temp1.append(row['batting_team_runs'] - row['bowling_team_runs'])
    elif row['batting_team_runs'] < row['bowling_team_runs']:
        temp1.append(row['bowling_team_runs'] - row['batting_team_runs'])
    else:
        temp1.append(0)

# %%
df1['run_margin']=temp1

# %%
for i, row in df1.iterrows():
    print('--------------------------------------------------------------------')
    print('The biggest win in terms of run margin is', df1['run_margin'].max())
    print('--------------------------------------------------------------------')
    print('The winner team is', row['winner'])
    print('--------------------------------------------------------------------')
    break
# Out:
# --------------------------------------------------------------------
# The biggest win in terms of run margin is 185
# --------------------------------------------------------------------
# The winner team is Kolkata Knight Riders
# --------------------------------------------------------------------

# %% [markdown]
# ## 20] Which batsmen have played the most number of balls?

# %%
#groups the data in DataFrame df by the 'batsman' column using the groupby() function.
#This step creates separate groups for each unique value in the 'batsman' column.
#Within each group, the code counts the number of balls faced by each batsman using the count() function applied to the 'ball' column.
#This step creates a Series where the index is the batsman's name and the values are the number of balls faced by each batsman.
#Resetting index: The code resets the index of the resulting Series using the reset_index() method to convert the Series to a DataFrame.
#This step ensures that the batsman names become a regular column in the DataFrame.
batsman_balls = df.groupby('batsman')['ball'].count().reset_index()

# %%
#meaningful names to the columns representing the batsman's name and the number of balls faced.
batsman_balls.columns = ['Batsman', 'Balls Faced']

# %%
# sorts the DataFrame in descending order based on the number of balls faced by each batsman.
batsman_balls = batsman_balls.sort_values(by='Balls Faced', ascending=False)

# %%
# prints the top batsmen who have faced the most number of balls.
print('-----------------------------------------------------------')
print("Batsmen who have played the most number of balls:")
for i,row in batsman_balls.iterrows():
    print(row['Batsman'],':',row['Balls Faced'])
    break
print('-----------------------------------------------------------')
# Out:
# -----------------------------------------------------------
# Batsmen who have played the most number of balls:
# V Kohli : 4609
# -----------------------------------------------------------

# %% [markdown]
# ## 21] Who are the leading run-scorers of all the time?

# %%
# Group the data by batsman and sum the runs scored by each batsman
batsman_score = df.groupby('batsman')['batsman_runs'].sum().reset_index()

# Sort the data in descending order based on runs scored
leading_run_scorers = batsman_score.sort_values(by='batsman_runs', ascending=False).reset_index()

# Print the leading run-scorers
print('--------------------------------------------------')
print("Leading run-scorers of all time:")
for i,row in leading_run_scorers.iterrows():
    print('--------------------------------------------------')
    print(row['batsman'],':', row['batsman_runs'])
    if i>5:
        break
print('--------------------------------------------------')
# Out:
# --------------------------------------------------
# Leading run-scorers of all time:
# --------------------------------------------------
# V Kohli : 5878
# --------------------------------------------------
# SK Raina : 5368
# --------------------------------------------------
# DA Warner : 5254
# --------------------------------------------------
# RG Sharma : 5230
# --------------------------------------------------
# S Dhawan : 5197
# --------------------------------------------------
# AB de Villiers : 4849
# --------------------------------------------------
# CH Gayle : 4772
# --------------------------------------------------

# %% [markdown]
# ## 22] Who has hit the most number of 4's?

# %%
#This line filters the dataset df to include only those deliveries where the batsman scored 4 runs.
#It creates a new DataFrame fours containing only the deliveries where 4 runs were scored.
fours = df[df['batsman_runs'] == 4]

# Count the occurrences of each batsman hitting a four
most_fours = fours['batsman'].value_counts()

# Identify the batsman with the most number of fours
batsman_most_fours = most_fours.idxmax()
num_fours = most_fours.max()

print('-------------------------------------------------------------------')
print("Batsman who has hit the most number of fours:", batsman_most_fours)
print('-------------------------------------------------------------------')
print("Number of fours:", num_fours)
print('-------------------------------------------------------------------')
# Out:
# -------------------------------------------------------------------
# Batsman who has hit the most number of fours: S Dhawan
# -------------------------------------------------------------------
# Number of fours: 591
# -------------------------------------------------------------------

# %% [markdown]
# ## 23] Who has hit the most number of 6's?

# %%
#This line filters the dataset df to include only those deliveries where the batsman scored 6 runs.
#It creates a new DataFrame six containing only the deliveries where 6 runs were scored.
six = df[df['batsman_runs'] == 6]

# Count the occurrences of each batsman hitting six
most_six = six['batsman'].value_counts()

# Identify the batsman with the most number of fours
batsman_most_six = most_six.idxmax()
num_six = most_six.max()

print('-------------------------------------------------------------------')
print("Batsman who has hit the most number of six:", batsman_most_six)
print('-------------------------------------------------------------------')
print("Number of six:", num_six)
print('-------------------------------------------------------------------')
# Out:
# -------------------------------------------------------------------
# Batsman who has hit the most number of six: CH Gayle
# -------------------------------------------------------------------
# Number of six: 349
# -------------------------------------------------------------------

# %% [markdown]
# ## 24] Who has the highest strike rate ?

# %%
# Calculate the total runs scored by each batsman
total_runs = df.groupby('batsman')['batsman_runs'].sum()

# Calculate the total balls faced by each batsman
total_balls_faced = df['batsman'].value_counts()

# Calculate the strike rate for each batsman
strike_rate = (total_runs / total_balls_faced) * 100

# Identify the batsman with the highest strike rate
highest_strike_rate_batsman = strike_rate.idxmax()
highest_strike_rate = strike_rate.max()

print('------------------------------------------------------------------')
print("Batsman with the highest strike rate:", highest_strike_rate_batsman)
print('------------------------------------------------------------------')
print("Highest strike rate:", highest_strike_rate)
print('------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------
# Batsman with the highest strike rate: B Stanlake
# ------------------------------------------------------------------
# Highest strike rate: 250.0
# ------------------------------------------------------------------

# %% [markdown]
# ## 25] Who is leading wicket-taker?

# %%
# Filter the dataset to include only deliveries where a wicket was taken
wickets = df[df['is_wicket'] == 1]

# Count the occurrences of each bowler taking a wicket
leading_wicket_taker = wickets['bowler'].value_counts()

# Identify the bowler with the most number of wickets
leading_wicket_taker_name = leading_wicket_taker.idxmax()
leading_wicket_count = leading_wicket_taker.max()

print('----------------------------------------------------')
print("Leading wicket-taker:", leading_wicket_taker_name)
print('----------------------------------------------------')
print("Number of wickets:", leading_wicket_count)
print('----------------------------------------------------')
# Out:
# ----------------------------------------------------
# Leading wicket-taker: SL Malinga
# ----------------------------------------------------
# Number of wickets: 188
# ----------------------------------------------------

# %% [markdown]
# ## 26] Which stadium has hosted the most number of matches?

# %%
most_matches_stadium = df1['venue'].value_counts()

# %%
most_matches_stadium=most_matches_stadium.sort_values(ascending=False).reset_index()

# %%
print('-------------------------------------------------------------')
for i,row in most_matches_stadium.iterrows():
    print('The stadium which has hosted most number of matches is')
    print(row['venue'],':',row['count'])
    break
print('-------------------------------------------------------------')
# Out:
# -------------------------------------------------------------
# The stadium which has hosted most number of matches is
# Eden Gardens : 77
# -------------------------------------------------------------

# %% [markdown]
# ## 27] Who has won the most MOM awards?

# %%
most_mom= df1['player_of_match'].value_counts()

# %%
most_mom= most_mom.sort_values(ascending=False).reset_index()

# %%
print('-------------------------------------------------')
print('The most man of the match(MOM) awards are won by')
print('-------------------------------------------------')
for i,row in most_mom.iterrows():
    print(row['player_of_match'],':',row['count'])
    break
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# The most man of the match(MOM) awards are won by
# -------------------------------------------------
# AB de Villiers : 23
# -------------------------------------------------

# %% [markdown]
# ## 28] What is the count of fours hit in each season?

# %%
four = df[df['batsman_runs']==4]

# %%
four
# Out:
#              id  inning  over  ball      batsman  non_striker  \
# 21       335982       1    10     2   RT Ponting  BB McCullum
# 33       335982       1    12     2  BB McCullum    DJ Hussey
# 37       335982       1    12     6  BB McCullum    DJ Hussey
# 45       335982       1    14     1    DJ Hussey  BB McCullum
# 48       335982       1    14     4  BB McCullum    DJ Hussey
# ...         ...     ...   ...   ...          ...          ...
# 193402  1237181       1     2     5      SS Iyer     S Dhawan
# 193411  1237181       1     4     2      SS Iyer      RR Pant
# 193414  1237181       1     4     5      SS Iyer      RR Pant
# 193420  1237181       1     5     5      SS Iyer      RR Pant
# 193454  1237181       1    11     3      RR Pant      SS Iyer
#
#                  bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 21            JH Kallis             4           0           4             0
# 33            JH Kallis             4           0           4             0
# 37            JH Kallis             4           0           4             0
# 45             CL White             4           0           4             0
# 48             CL White             4           0           4             0
# ...                 ...           ...         ...         ...           ...
# 193402         TA Boult             4           0           4             0
# 193411         TA Boult             4           0           4             0
# 193414         TA Boult             4           0           4             0
# 193420  NM Coulter-Nile             4           0           4             0
# 193454       KA Pollard             4           0           4             0
#
#         is_wicket           batting_team                 bowling_team
# 21              0  Kolkata Knight Riders  Royal Challengers Bangalore
# 33              0  Kolkata Knight Riders  Royal Challengers Bangalore
# 37              0  Kolkata Knight Riders  Royal Challengers Bangalore
# 45              0  Kolkata Knight Riders  Royal Challengers Bangalore
# 48              0  Kolkata Knight Riders  Royal Challengers Bangalore
# ...           ...                    ...                          ...
# 193402          0         Delhi Capitals               Mumbai Indians
# 193411          0         Delhi Capitals               Mumbai Indians
# 193414          0         Delhi Capitals               Mumbai Indians
# 193420          0         Delhi Capitals               Mumbai Indians
# 193454          0         Delhi Capitals               Mumbai Indians
#
# [21908 rows x 14 columns]

# %%
season1=[]
season2=[]
season3=[]
season4=[]
season5=[]
season6=[]
season7=[]
season8=[]
season9=[]
season10=[]
season11=[]
season12=[]
season13=[]

#creating a function to create list of ids for each season
def fours_per_season(year,lst):
    for i,row in df1.iterrows():
        if row['Year']==year:
            lst.append(row['id'])
    print([min(lst), max(lst)])

# %%
fours_per_season(2008,season1)
# Out:
# [335982, 336040]

# %%
fours_per_season(2009,season2)
# Out:
# [392181, 392239]

# %%
fours_per_season(2010,season3)
# Out:
# [419106, 419165]

# %%
fours_per_season(2011,season4)
# Out:
# [501198, 501271]

# %%
fours_per_season(2012,season5)
# Out:
# [548306, 548381]

# %%
fours_per_season(2013,season6)
# Out:
# [597998, 598073]

# %%
fours_per_season(2014,season7)
# Out:
# [729279, 734049]

# %%
fours_per_season(2015,season8)
# Out:
# [829705, 829823]

# %%
fours_per_season(2016,season9)
# Out:
# [980901, 981019]

# %%
fours_per_season(2017,season10)
# Out:
# [1082591, 1082650]

# %%
fours_per_season(2018,season11)
# Out:
# [1136561, 1136620]

# %%
fours_per_season(2019,season12)
# Out:
# [1175356, 1181768]

# %%
fours_per_season(2020,season13)
# Out:
# [1216492, 1237181]

# %%
def no_of_fours_per_season(lst,season,year):    
   
    count=0
    for i,row in four.iterrows():
        if(row['id']>= min(lst) and row['id']<=max(lst)):
            count =count+1
    print('---------------------------------------------------------------------')
    print(season,'(i.e., year',year,')',' :', count)

# %%
print('*************** Count of Fours scored in each season********************')
fours =[]
fours.append([no_of_fours_per_season(season1,'season 1',2008)])
fours.append([no_of_fours_per_season(season2,'season 2',2009)])
fours.append([no_of_fours_per_season(season3,'season 3',2010)])
fours.append([no_of_fours_per_season(season4,'season 4',2011)])
fours.append([no_of_fours_per_season(season5,'season 5',2012)])
fours.append([no_of_fours_per_season(season6,'season 6',2013)])
fours.append([no_of_fours_per_season(season7,'season 7',2014)])
fours.append([no_of_fours_per_season(season8,'season 8',2015)])
fours.append([no_of_fours_per_season(season9,'season 9',2016)])
fours.append([no_of_fours_per_season(season10,'season 10',2017)])
fours.append([no_of_fours_per_season(season11,'season 11',2018)])
fours.append([no_of_fours_per_season(season12,'season 12',2019)])
fours.append([no_of_fours_per_season(season13,'season 13',2020)])
print('---------------------------------------------------------------------')
# Out:
# *************** Count of Fours scored in each season********************
# ---------------------------------------------------------------------
# season 1 (i.e., year 2008 )  : 1703
# ---------------------------------------------------------------------
# season 2 (i.e., year 2009 )  : 1317
# ---------------------------------------------------------------------
# season 3 (i.e., year 2010 )  : 1708
# ---------------------------------------------------------------------
# season 4 (i.e., year 2011 )  : 1916
# ---------------------------------------------------------------------
# season 5 (i.e., year 2012 )  : 1911
# ---------------------------------------------------------------------
# season 6 (i.e., year 2013 )  : 2052
# ---------------------------------------------------------------------
# season 7 (i.e., year 2014 )  : 1562
# ---------------------------------------------------------------------
# season 8 (i.e., year 2015 )  : 1607
# ---------------------------------------------------------------------
# season 9 (i.e., year 2016 )  : 1633
# ---------------------------------------------------------------------
# season 10 (i.e., year 2017 )  : 1611
# ---------------------------------------------------------------------
# season 11 (i.e., year 2018 )  : 1652
# ---------------------------------------------------------------------
# season 12 (i.e., year 2019 )  : 1653
# ---------------------------------------------------------------------
# season 13 (i.e., year 2020 )  : 1583
# ---------------------------------------------------------------------

# %% [markdown]
# ## 29] What is the count of sixes hit in each season? What is the count of runs scored from boundaries in each season?

# %%
six = df[df['batsman_runs']==6]

# %%
six
# Out:
#              id  inning  over  ball       batsman  non_striker  \
# 18       335982       1     9     5   BB McCullum   RT Ponting
# 23       335982       1    10     4    RT Ponting  BB McCullum
# 27       335982       1    11     2   BB McCullum   RT Ponting
# 47       335982       1    14     3   BB McCullum    DJ Hussey
# 51       335982       1    14     7   BB McCullum    DJ Hussey
# ...         ...     ...   ...   ...           ...          ...
# 193352  1237181       2    14     4  Ishan Kishan    RG Sharma
# 193384  1237181       1    19     5       SS Iyer     K Rabada
# 193441  1237181       1     9     2       RR Pant      SS Iyer
# 193444  1237181       1     9     5       RR Pant      SS Iyer
# 193458  1237181       1    11     7       SS Iyer      RR Pant
#
#                  bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 18             SB Joshi             6           0           6             0
# 23            JH Kallis             6           0           6             0
# 27             SB Joshi             6           0           6             0
# 47             CL White             6           0           6             0
# 51             CL White             6           0           6             0
# ...                 ...           ...         ...         ...           ...
# 193352       MP Stoinis             6           0           6             0
# 193384  NM Coulter-Nile             6           0           6             0
# 193441        KH Pandya             6           0           6             0
# 193444        KH Pandya             6           0           6             0
# 193458       KA Pollard             6           0           6             0
#
#         is_wicket           batting_team                 bowling_team
# 18              0  Kolkata Knight Riders  Royal Challengers Bangalore
# 23              0  Kolkata Knight Riders  Royal Challengers Bangalore
# 27              0  Kolkata Knight Riders  Royal Challengers Bangalore
# 47              0  Kolkata Knight Riders  Royal Challengers Bangalore
# 51              0  Kolkata Knight Riders  Royal Challengers Bangalore
# ...           ...                    ...                          ...
# 193352          0         Mumbai Indians               Delhi Capitals
# 193384          0         Delhi Capitals               Mumbai Indians
# 193441          0         Delhi Capitals               Mumbai Indians
# 193444          0         Delhi Capitals               Mumbai Indians
# 193458          0         Delhi Capitals               Mumbai Indians
#
# [8902 rows x 14 columns]

# %%
def no_of_sixes_per_season(lst,season,year):    
   
    count=0
    for i,row in six.iterrows():
        if(row['id']>= min(lst) and row['id']<=max(lst)):
            count =count+1
    print('---------------------------------------------------------------------')
    print(season,'(i.e., year',year,')',' :', count)

# %%
print('*************** Count of sixes scored in each season********************')
sixes =[]
sixes.append([no_of_sixes_per_season(season1,'season 1',2008)])
sixes.append([no_of_sixes_per_season(season2,'season 2',2009)])
sixes.append([no_of_sixes_per_season(season3,'season 3',2010)])
sixes.append([no_of_sixes_per_season(season4,'season 4',2011)])
sixes.append([no_of_sixes_per_season(season5,'season 5',2012)])
sixes.append([no_of_sixes_per_season(season6,'season 6',2013)])
sixes.append([no_of_sixes_per_season(season7,'season 7',2014)])
sixes.append([no_of_sixes_per_season(season8,'season 8',2015)])
sixes.append([no_of_sixes_per_season(season9,'season 9',2016)])
sixes.append([no_of_sixes_per_season(season10,'season 10',2017)])
sixes.append([no_of_sixes_per_season(season11,'season 11',2018)])
sixes.append([no_of_sixes_per_season(season12,'season 12',2019)])
sixes.append([no_of_sixes_per_season(season13,'season 13',2020)])
print('---------------------------------------------------------------------')
# Out:
# *************** Count of sixes scored in each season********************
# ---------------------------------------------------------------------
# season 1 (i.e., year 2008 )  : 623
# ---------------------------------------------------------------------
# season 2 (i.e., year 2009 )  : 506
# ---------------------------------------------------------------------
# season 3 (i.e., year 2010 )  : 585
# ---------------------------------------------------------------------
# season 4 (i.e., year 2011 )  : 639
# ---------------------------------------------------------------------
# season 5 (i.e., year 2012 )  : 733
# ---------------------------------------------------------------------
# season 6 (i.e., year 2013 )  : 675
# ---------------------------------------------------------------------
# season 7 (i.e., year 2014 )  : 714
# ---------------------------------------------------------------------
# season 8 (i.e., year 2015 )  : 692
# ---------------------------------------------------------------------
# season 9 (i.e., year 2016 )  : 639
# ---------------------------------------------------------------------
# season 10 (i.e., year 2017 )  : 705
# ---------------------------------------------------------------------
# season 11 (i.e., year 2018 )  : 872
# ---------------------------------------------------------------------
# season 12 (i.e., year 2019 )  : 784
# ---------------------------------------------------------------------
# season 13 (i.e., year 2020 )  : 735
# ---------------------------------------------------------------------

# %%
boundary=df[(df['non_boundary'] == 0) & ((df['batsman_runs'] == 4) | (df['batsman_runs'] == 6))]

# %%
boundary=boundary.reset_index()

# %%
boundary
# Out:
#         index       id  inning  over  ball      batsman  non_striker  \
# 0          18   335982       1     9     5  BB McCullum   RT Ponting
# 1          21   335982       1    10     2   RT Ponting  BB McCullum
# 2          23   335982       1    10     4   RT Ponting  BB McCullum
# 3          27   335982       1    11     2  BB McCullum   RT Ponting
# 4          33   335982       1    12     2  BB McCullum    DJ Hussey
# ...       ...      ...     ...   ...   ...          ...          ...
# 30789  193420  1237181       1     5     5      SS Iyer      RR Pant
# 30790  193441  1237181       1     9     2      RR Pant      SS Iyer
# 30791  193444  1237181       1     9     5      RR Pant      SS Iyer
# 30792  193454  1237181       1    11     3      RR Pant      SS Iyer
# 30793  193458  1237181       1    11     7      SS Iyer      RR Pant
#
#                 bowler  batsman_runs  extra_runs  total_runs  non_boundary  \
# 0             SB Joshi             6           0           6             0
# 1            JH Kallis             4           0           4             0
# 2            JH Kallis             6           0           6             0
# 3             SB Joshi             6           0           6             0
# 4            JH Kallis             4           0           4             0
# ...                ...           ...         ...         ...           ...
# 30789  NM Coulter-Nile             4           0           4             0
# 30790        KH Pandya             6           0           6             0
# 30791        KH Pandya             6           0           6             0
# 30792       KA Pollard             4           0           4             0
# 30793       KA Pollard             6           0           6             0
#
#        is_wicket           batting_team                 bowling_team
# 0              0  Kolkata Knight Riders  Royal Challengers Bangalore
# 1              0  Kolkata Knight Riders  Royal Challengers Bangalore
# 2              0  Kolkata Knight Riders  Royal Challengers Bangalore
# 3              0  Kolkata Knight Riders  Royal Challengers Bangalore
# 4              0  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...                    ...                          ...
# 30789          0         Delhi Capitals               Mumbai Indians
# 30790          0         Delhi Capitals               Mumbai Indians
# 30791          0         Delhi Capitals               Mumbai Indians
# 30792          0         Delhi Capitals               Mumbai Indians
# 30793          0         Delhi Capitals               Mumbai Indians
#
# [30794 rows x 15 columns]

# %%
def no_of_boundary_per_season(lst,season,year):    
   
    add=0
    for i,row in boundary.iterrows():
        if(row['id']>= min(lst) and row['id']<=max(lst)):
            add = add + row['batsman_runs']
    print('---------------------------------------------------------------------')
    print(season,'(i.e., year',year,')',' :', add)

# %%
print('*************** Count of runs scored from boundaries in each season********************')
runs =[]
runs.append([no_of_boundary_per_season(season1,'season 1',2008)])
runs.append([no_of_boundary_per_season(season2,'season 2',2009)])
runs.append([no_of_boundary_per_season(season3,'season 3',2010)])
runs.append([no_of_boundary_per_season(season4,'season 4',2011)])
runs.append([no_of_boundary_per_season(season5,'season 5',2012)])
runs.append([no_of_boundary_per_season(season6,'season 6',2013)])
runs.append([no_of_boundary_per_season(season7,'season 7',2014)])
runs.append([no_of_boundary_per_season(season8,'season 8',2015)])
runs.append([no_of_boundary_per_season(season9,'season 9',2016)])
runs.append([no_of_boundary_per_season(season10,'season 10',2017)])
runs.append([no_of_boundary_per_season(season11,'season 11',2018)])
runs.append([no_of_boundary_per_season(season12,'season 12',2019)])
runs.append([no_of_boundary_per_season(season13,'season 13',2020)])
print('---------------------------------------------------------------------')
# Out:
# *************** Count of runs scored from boundaries in each season********************
# ---------------------------------------------------------------------
# season 1 (i.e., year 2008 )  : 10544
# ---------------------------------------------------------------------
# season 2 (i.e., year 2009 )  : 8300
# ---------------------------------------------------------------------
# season 3 (i.e., year 2010 )  : 10342
# ---------------------------------------------------------------------
# season 4 (i.e., year 2011 )  : 11486
# ---------------------------------------------------------------------
# season 5 (i.e., year 2012 )  : 12030
# ---------------------------------------------------------------------
# season 6 (i.e., year 2013 )  : 12248
# ---------------------------------------------------------------------
# season 7 (i.e., year 2014 )  : 10532
# ---------------------------------------------------------------------
# season 8 (i.e., year 2015 )  : 10580
# ---------------------------------------------------------------------
# season 9 (i.e., year 2016 )  : 10356
# ---------------------------------------------------------------------
# season 10 (i.e., year 2017 )  : 10666
# ---------------------------------------------------------------------
# season 11 (i.e., year 2018 )  : 11836
# ---------------------------------------------------------------------
# season 12 (i.e., year 2019 )  : 11316
# ---------------------------------------------------------------------
# season 13 (i.e., year 2020 )  : 10732
# ---------------------------------------------------------------------

# %% [markdown]
# ## 30] What is the run contribution from boundaries in each season?

# %%
def boundary_run_contribution_per_season(lst,season,year):    
   
    add=0
    total_runs_per_season=0
    for i,row in boundary.iterrows():
        if(row['id']>= min(lst) and row['id']<=max(lst)):
            add = add + row['batsman_runs']
    for i,row in df1.iterrows():
        if(row['Year']==year):
            total_runs_per_season = total_runs_per_season+row['runs_per_match']   
            boundary_contribution_per_season = (add / total_runs_per_season) * 100
    print('-----------------------------------------------------------------------------')
    print('The run contibution from boundaries in each season is')
    print(season,'(i.e.,year,',year,' ) : ',boundary_contribution_per_season,'%')

# %%
print('*********** Count of runs contibution from boundaries in each season*************')
contribution =[]
contribution.append([boundary_run_contribution_per_season(season1,'season 1',2008)])
contribution.append([boundary_run_contribution_per_season(season2,'season 2',2009)])
contribution.append([boundary_run_contribution_per_season(season3,'season 3',2010)])
contribution.append([boundary_run_contribution_per_season(season4,'season 4',2011)])
contribution.append([boundary_run_contribution_per_season(season5,'season 5',2012)])
contribution.append([boundary_run_contribution_per_season(season6,'season 6',2013)])
contribution.append([boundary_run_contribution_per_season(season7,'season 7',2014)])
contribution.append([boundary_run_contribution_per_season(season8,'season 8',2015)])
contribution.append([boundary_run_contribution_per_season(season9,'season 9',2016)])
contribution.append([boundary_run_contribution_per_season(season10,'season 10',2017)])
contribution.append([boundary_run_contribution_per_season(season11,'season 11',2018)])
contribution.append([boundary_run_contribution_per_season(season12,'season 12',2019)])
contribution.append([boundary_run_contribution_per_season(season13,'season 13',2020)])
print('---------------------------------------------------------------------------------')
# Out:
# *********** Count of runs contibution from boundaries in each season*************
# -----------------------------------------------------------------------------
# The run contibution from boundaries in each season is
# season 1 (i.e.,year, 2008  ) :  58.7835200981212 %
# -----------------------------------------------------------------------------
# The run contibution from boundaries in each season is
# season 2 (i.e.,year, 2009  ) :  50.857843137254896 %
# -----------------------------------------------------------------------------
# The run contibution from boundaries in each season is
# season 3 (i.e.,year, 2010  ) :  54.82400339270568 %
# -----------------------------------------------------------------------------
# The run contibution from boundaries in each season is
# season 4 (i.e.,year, 2011  ) :  54.4411792586975 %
# -----------------------------------------------------------------------------
# The run contibution from boundaries in each season is
# season 5 (i.e.,year, 2012  ) :  53.57858638043914 %
# -----------------------------------------------------------------------------
# The run contibution from boundaries in each season is
# season 6 (i.e.,year, 2013  ) :  54.33654230069651 %
# -----------------------------------------------------------------------------
# The run contibution from boundaries in each season is
# season 7 (i.e.,year, 2014  ) :  55.698344703580304 %
# -----------------------------------------------------------------------------
# The run contibution from boundaries in each season is
# season 8 (i.e.,year, 2015  ) :  57.71328823914467 %
# -----------------------------------------------------------------------------
# The run contibution from boundaries in each season is
# season 9 (i.e.,year, 2016  ) :  54.904039868518716 %
# -----------------------------------------------------------------------------
# The run contibution from boundaries in each season is
# season 10 (i.e.,year, 2017  ) :  56.8277478821461 %
# -----------------------------------------------------------------------------
# The run contibution from boundaries in each season is
# season 11 (i.e.,year, 2018  ) :  59.474398271443654 %
# -----------------------------------------------------------------------------
# The run contibution from boundaries in each season is
# season 12 (i.e.,year, 2019  ) :  58.329896907216494 %
# -----------------------------------------------------------------------------
# The run contibution from boundaries in each season is
# season 13 (i.e.,year, 2020  ) :  55.456800330715176 %
# ---------------------------------------------------------------------------------

# %% [markdown]
# ## 31] Which team has scored the most runs in first 6 overs?

# %%
first_6_overs=df[df['over']<=6]

# %%
runs_in_first_6_overs=first_6_overs.groupby('batting_team')['batsman_runs'].sum()

# %%
most_runs_in_first_6_overs = runs_in_first_6_overs.sort_values(ascending=False).reset_index()

# %%
most_runs_in_first_6_overs
# Out:
#                    batting_team  batsman_runs
# 0                Mumbai Indians          9734
# 1               Kings XI Punjab          9677
# 2         Kolkata Knight Riders          9494
# 3   Royal Challengers Bangalore          9357
# 4           Chennai Super Kings          8732
# 5              Delhi Daredevils          7957
# 6              Rajasthan Royals          7750
# 7           Sunrisers Hyderabad          6308
# 8               Deccan Chargers          3651
# 9                 Pune Warriors          2008
# 10               Delhi Capitals          1718
# 11                Gujarat Lions          1717
# 12       Rising Pune Supergiant           835
# 13      Rising Pune Supergiants           709
# 14         Kochi Tuskers Kerala           697

# %%
for i,row in most_runs_in_first_6_overs.iterrows():
    print('---------------------------------------------------------')
    print('The team which has scored most runs in first 6 overs is')
    print(row['batting_team'] ,':',row['batsman_runs'])
    print('---------------------------------------------------------')
    break
# Out:
# ---------------------------------------------------------
# The team which has scored most runs in first 6 overs is
# Mumbai Indians : 9734
# ---------------------------------------------------------

# %% [markdown]
# ## 32] Which team has scored the most runs in last 4 overs?

# %%
last_4_overs=df[df['over']>=17]

# %%
runs_in_last_4_overs=last_4_overs.groupby('batting_team')['batsman_runs'].sum()

# %%
most_runs_in_last_4_overs = runs_in_last_4_overs.sort_values(ascending=False).reset_index()

# %%
most_runs_in_last_4_overs
# Out:
#                    batting_team  batsman_runs
# 0                Mumbai Indians          5410
# 1   Royal Challengers Bangalore          4843
# 2           Chennai Super Kings          4784
# 3               Kings XI Punjab          4398
# 4         Kolkata Knight Riders          4277
# 5              Delhi Daredevils          3524
# 6              Rajasthan Royals          3453
# 7           Sunrisers Hyderabad          3024
# 8               Deccan Chargers          1738
# 9                 Pune Warriors           993
# 10               Delhi Capitals           800
# 11                Gujarat Lions           623
# 12       Rising Pune Supergiant           412
# 13      Rising Pune Supergiants           312
# 14         Kochi Tuskers Kerala           236

# %%
for i,row in most_runs_in_last_4_overs.iterrows():
    print('--------------------------------------------------')
    print('The team which has scored most runs in last 4 overs is')
    print(row['batting_team'] ,':',row['batsman_runs'])
    print('--------------------------------------------------')
    break
# Out:
# --------------------------------------------------
# The team which has scored most runs in last 4 overs is
# Mumbai Indians : 5410
# --------------------------------------------------

# %% [markdown]
# ## 33] Which team has the best scoring run-rate in the first 6 overs ?

# %%
first_6_overs=df[df['over']<=6]

# %%
runs_in_first_6_overs=first_6_overs.groupby('batting_team')['batsman_runs'].sum().reset_index()

# %%
most_runs_in_first_6_overs = runs_in_first_6_overs.sort_values(by='batsman_runs',ascending=False).reset_index()

# %%
most_runs_in_first_6_overs
# Out:
#     index                 batting_team  batsman_runs
# 0       8               Mumbai Indians          9734
# 1       5              Kings XI Punjab          9677
# 2       7        Kolkata Knight Riders          9494
# 3      13  Royal Challengers Bangalore          9357
# 4       0          Chennai Super Kings          8732
# 5       3             Delhi Daredevils          7957
# 6      10             Rajasthan Royals          7750
# 7      14          Sunrisers Hyderabad          6308
# 8       1              Deccan Chargers          3651
# 9       9                Pune Warriors          2008
# 10      2               Delhi Capitals          1718
# 11      4                Gujarat Lions          1717
# 12     11       Rising Pune Supergiant           835
# 13     12      Rising Pune Supergiants           709
# 14      6         Kochi Tuskers Kerala           697

# %%
unique_teams=[]
for i,row in most_runs_in_first_6_overs.iterrows():
    unique_teams.append(row['batting_team'])

# %%
def run_rate_6(team):    
    count=0
    for i,row in first_6_overs.iterrows():
        for i in unique_teams:
            if (row['batting_team'] == team):
                count=count+ 1
    return count

# %%
a=[]
for i in unique_teams:
    a.append(run_rate_6(i))

# %%
unique_teams
# Out:
# ['Mumbai Indians',
#  'Kings XI Punjab',
#  'Kolkata Knight Riders',
#  'Royal Challengers Bangalore',
#  'Chennai Super Kings',
#  'Delhi Daredevils',
#  'Rajasthan Royals',
#  'Sunrisers Hyderabad',
#  'Deccan Chargers',
#  'Pune Warriors',
#  'Delhi Capitals',
#  'Gujarat Lions',
#  'Rising Pune Supergiant',
#  'Rising Pune Supergiants',
#  'Kochi Tuskers Kerala']

# %%
a
# Out:
# [133485,
#  124200,
#  125565,
#  126480,
#  116220,
#  105060,
#  103995,
#  80880,
#  49170,
#  29370,
#  21405,
#  19635,
#  10455,
#  9135,
#  9330]

# %%
rate=[]
for i,row in most_runs_in_first_6_overs.iterrows():
    for i in a:
        run_rate=row['batsman_runs']/i
        rate.append(run_rate)
        break

# %%
print('-------------------------------------------------------------------')
print('The team which has the best scoring run rate in first 6 overs is')
print(unique_teams[0],':',max(rate))
print('-------------------------------------------------------------------')
# Out:
# -------------------------------------------------------------------
# The team which has the best scoring run rate in first 6 overs is
# Mumbai Indians : 0.07292205116679777
# -------------------------------------------------------------------

# %% [markdown]
# ## 34] Which team has the best scoring run-rate in the last 4 overs ?
# ​

# %%
last_4_overs=df[df['over']>=17]

# %%
runs_in_last_4_overs=last_4_overs.groupby('batting_team')['batsman_runs'].sum()

# %%
most_runs_in_last_4_overs = runs_in_last_4_overs.sort_values(ascending=False).reset_index()

# %%
most_runs_in_last_4_overs
# Out:
#                    batting_team  batsman_runs
# 0                Mumbai Indians          5410
# 1   Royal Challengers Bangalore          4843
# 2           Chennai Super Kings          4784
# 3               Kings XI Punjab          4398
# 4         Kolkata Knight Riders          4277
# 5              Delhi Daredevils          3524
# 6              Rajasthan Royals          3453
# 7           Sunrisers Hyderabad          3024
# 8               Deccan Chargers          1738
# 9                 Pune Warriors           993
# 10               Delhi Capitals           800
# 11                Gujarat Lions           623
# 12       Rising Pune Supergiant           412
# 13      Rising Pune Supergiants           312
# 14         Kochi Tuskers Kerala           236

# %%
unique_teams=[]
for i,row in most_runs_in_last_4_overs.iterrows():
    unique_teams.append(row['batting_team'])

# %%
def run_rate_4(team):    
    count=0
    for i,row in last_4_overs.iterrows():
        for i in unique_teams:
            if (row['batting_team'] == team):
                count=count+ 1
    return count

# %%
a1=[]
for i in unique_teams:
    a1.append(run_rate_4(i))

# %%
unique_teams
# Out:
# ['Mumbai Indians',
#  'Royal Challengers Bangalore',
#  'Chennai Super Kings',
#  'Kings XI Punjab',
#  'Kolkata Knight Riders',
#  'Delhi Daredevils',
#  'Rajasthan Royals',
#  'Sunrisers Hyderabad',
#  'Deccan Chargers',
#  'Pune Warriors',
#  'Delhi Capitals',
#  'Gujarat Lions',
#  'Rising Pune Supergiant',
#  'Rising Pune Supergiants',
#  'Kochi Tuskers Kerala']

# %%
a1
# Out:
# [49110,
#  43140,
#  43110,
#  44550,
#  41880,
#  33780,
#  35790,
#  29505,
#  18255,
#  10950,
#  8220,
#  6570,
#  3900,
#  2790,
#  2610]

# %%
rate1=[]
for i,row in most_runs_in_last_4_overs.iterrows():
    for i in a1:
        run_rate=row['batsman_runs']/i
        rate1.append(run_rate)
        break

# %%
print('-------------------------------------------------------------------')
print('The team which has the best scoring run rate in last 4 overs is')
print(unique_teams[0],':',max(rate1))
print('-------------------------------------------------------------------')
# Out:
# -------------------------------------------------------------------
# The team which has the best scoring run rate in last 4 overs is
# Mumbai Indians : 0.1101608633679495
# -------------------------------------------------------------------
